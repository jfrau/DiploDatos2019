# %% [markdown]
# <center>
# <h4>Universidad Nacional de Córdoba - Facultad de Matemática, Astronomía, Física y Computación</h4>
# <h3>Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones</h3>
# </center>

# %% [markdown]
# ### Aprendizaje NO supervisado - 2019
# #### Práctico: Reglas de Asociación
#
# Integrantes: Johanna Frau, Lucía Benítez y Nair Trógolo

# %% [markdown]
# #### Tarea:
#
# * Obtener reglas de asociación entre películas en el dataset movilents
# * Aplicar diferentes métricas de ordenamiento

# %% [markdown]
# En estre práctico se va a trabajar sobre el dataset MovieLens 20M Dataset (https://grouplens.org/datasets/movielens/20m/) que describe ratings y free-text tagging activities de MovieLens,que es un servicio de recomendación de películas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from efficient_apriori import apriori
from itertools import combinations, groupby

# %%
np.random.seed(1234) #para hacer reproducible el experimento

# %% [markdown]
# No se incluye información demográfica. Cada usuario está representado solo por un id.
# Los datos se distribuyen en seis archivos:
#
# * **tags.csv**, contiene las etiquetas aplicadas de las películas, por los usuarios:
#
#     * userId
#     * movieId
#     * tag
#     * timestamp
#
# * **ratings.csv**, contiene los ratings de las películas por los usuarios:
#
#     * userId
#     * movieId
#     * rating
#     * timestamp
#
# * **movies.csv**, contiene la información de la película:
#     * movieId
#     * title
#     * genres
#
# * **links.csv** contiene identificadores que pueden ser usados para acceder a otras fuentes:
#     * movieId
#     * imdbId
#     * tmbdId
#
# * **genome-scores.csv** contiene etiquetas de relevancia para la película:
#     * movieId
#     * tagId
#     * relevance
#
# * **genome-tags.csv** contiene la descripción de las etiquetas:
#     * tagId
#     * tag

# %% [markdown]
# Vamos a analizar especialmente los archivos: *ratings.csv* y *movies.csv*, ya que queremos encontrar reglas de asociación entre películas y los usuarios (como sistema de recomendación)

# %%
movies = pd.read_csv('movies_1.csv')
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
movies.sample(5)
# Out:
#       movieId                                      title  \
# 5443    26003  Night and Fog (Nuit et brouillard) (1955)
# 3134     4218                        River's Edge (1986)
# 2888     3863                           Cell, The (2000)
# 8443   111817             Jimi: All Is by My Side (2013)
# 1165     1545                             Ponette (1996)
#
#                      genres
# 5443  Crime|Documentary|War
# 3134            Crime|Drama
# 2888  Drama|Horror|Thriller
# 8443                  Drama
# 1165                  Drama

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
# movieId    9742 non-null int64
# title      9742 non-null object
# genres     9742 non-null object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %% [markdown]
# El dataset de movies tiene 3 columnas de features:
#
# - Identificador de Películas (movieId)
# - Título de la película junto con el año de lanzamiento (title)
# - Géneros a los cuales pertenece la película (genres).

# %%
new_movies = movies
new_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Preparación de los datos
#
# ### Creación de la columna year

# %% [markdown]
# Ahora crearemos una nueva columna que contenga sólo el año de las películas.

# %%
new_movies['year'] = new_movies['title'].str.rsplit(')',1).str[0].str.rsplit('(',1).str[1]
new_movies['year'].head()
# Out:
# 0    1995
# 1    1995
# 2    1995
# 3    1995
# 4    1995
# Name: year, dtype: object

# %% [markdown]
# Veamos si dicha columna quedó bien chequeando los valores únicos.

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '2005', '2006', '1902', nan, '1903', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '1908', '2006–2007'], dtype=object)

# %% [markdown]
# Observamos que dado que hay un valor anómalo en la columna year como 2006–2007 y también valores nulos.
#
# Procedemos a declarar estos índices como 'no year'.

# %%
new_movies[new_movies['year']=='2006–2007']
# Out:
#       movieId                              title              genres  \
# 9518   171749  Death Note: Desu nôto (2006–2007)  (no genres listed)
#
#            year
# 9518  2006–2007

# %%
new_movies.at[9518, 'year'] = 'no year'

# %% [markdown]
# Chequeamos nuevamente los valores únicos en la columna year.

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '2005', '2006', '1902', nan, '1903', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '1908', 'no year'], dtype=object)

# %% [markdown]
# En las filas con valores nulos colocamos la categoría "no year".

# %%
year_null = new_movies[new_movies['year'].isnull()]

# %%
index_year_null = np.array(year_null.index)
index_year_null
# Out:
# array([6059, 9031, 9091, 9138, 9179, 9259, 9367, 9448, 9514, 9515, 9525,
#        9611])

# %%
new_movies.at[index_year_null, 'year'] = 'no year'

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '2005', '2006', '1902', 'no year', '1903', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '1908'], dtype=object)

# %%
new_movies.sample(5)
# Out:
#       movieId                                              title  \
# 8172   102760                                Down Terrace (2009)
# 3292     4452                                        Made (2001)
# 9577   174727                                   Good Time (2017)
# 1119     1459                              Absolute Power (1997)
# 4386     6433  Man with the Movie Camera, The (Chelovek s kin...
#
#                   genres  year
# 8172  Comedy|Crime|Drama  2009
# 3292              Comedy  2001
# 9577         Crime|Drama  2017
# 1119    Mystery|Thriller  1997
# 4386         Documentary  1929

# %% [markdown]
# ### Creación de la columna con sólo el título

# %%
new_movies['only_title'] = new_movies['title'].str.rsplit('(',1).str[0]
new_movies.sample(5)
# Out:
#       movieId                                       title            genres  \
# 7553    85334                Hard Ticket to Hawaii (1987)     Action|Comedy
# 4847     7245                            Tormented (1960)   Horror|Thriller
# 726       946                   To Be or Not to Be (1942)  Comedy|Drama|War
# 8939   136447  George Carlin: You Are All Diseased (1999)            Comedy
# 5354     8921                     Rose Tattoo, The (1955)     Drama|Romance
#
#       year                            only_title
# 7553  1987                Hard Ticket to Hawaii
# 4847  1960                            Tormented
# 726   1942                   To Be or Not to Be
# 8939  1999  George Carlin: You Are All Diseased
# 5354  1955                     Rose Tattoo, The

# %% [markdown]
# ## Rating dataset

# %%
rating = pd.read_csv('ratings_1.csv')
rating.sample(5)
# Out:
#        userId  movieId  rating   timestamp
# 1320       11     2002     2.0   902154383
# 24583     169     8008     5.0  1085699657
# 83600     534      393     4.0  1459789158
# 10330      67     1270     4.5  1501273836
# 24533     169     5941     4.0  1070250515

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
# userId       100836 non-null int64
# movieId      100836 non-null int64
# rating       100836 non-null float64
# timestamp    100836 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %% [markdown]
# El dataset de rating contiene 4 columnas de features:
#
# - Identificador de usuario (userId)
# - Identificador de películas (movieId)
# - Rating de la película (rating)
# - timestamp (no necesario)

# %%
rating = rating.loc[:,["userId","movieId","rating"]]
rating.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %% [markdown]
# Vamos a proceder a unir los dos dataset mediante el Id de las películas.

# %%
df = pd.merge(rating,new_movies, on='movieId')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 7 columns):
# userId        100836 non-null int64
# movieId       100836 non-null int64
# rating        100836 non-null float64
# title         100836 non-null object
# genres        100836 non-null object
# year          100836 non-null object
# only_title    100836 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.2+ MB

# %%
df.head(10)
# Out:
#    userId  movieId  rating             title  \
# 0       1        1     4.0  Toy Story (1995)
# 1       5        1     4.0  Toy Story (1995)
# 2       7        1     4.5  Toy Story (1995)
# 3      15        1     2.5  Toy Story (1995)
# 4      17        1     4.5  Toy Story (1995)
# 5      18        1     3.5  Toy Story (1995)
# 6      19        1     4.0  Toy Story (1995)
# 7      21        1     3.5  Toy Story (1995)
# 8      27        1     3.0  Toy Story (1995)
# 9      31        1     5.0  Toy Story (1995)
#
#                                         genres  year  only_title
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 1  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 2  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 3  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 4  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 5  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 6  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 7  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 8  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story
# 9  Adventure|Animation|Children|Comedy|Fantasy  1995  Toy Story

# %%
#final_df = df.sample(frac= 0.5)
#final_df.info()

# %% [markdown]
# #### Visualización y análisis exploratorio de datos:

# %%
plt.figure(figsize=(15,7.5))
sns.set(style="darkgrid")
sns.distplot(df['rating'].dropna(), bins=10, kde=False, hist_kws={'edgecolor':'black'})
sns.despine()

# %%
avg_ratings= df.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.920930
# 1        2  3.431818
# 2        3  3.259615
# 3        4  2.357143
# 4        5  3.071429

# %%
mov_avg_rtg = movies.merge(avg_ratings, on='movieId', how='inner')
mov_avg_rtg.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
#
#                      only_title    rating
# 0                    Toy Story   3.920930
# 1                      Jumanji   3.431818
# 2             Grumpier Old Men   3.259615
# 3            Waiting to Exhale   2.357143
# 4  Father of the Bride Part II   3.071429

# %%
# all users and individual ratings count.
dftmp = rating[['userId', 'movieId']].groupby('movieId').count()
dftmp.columns=['num_ratings']

# %%
n=200 #con la base entera, n=40000
# Let's check those movies with +40k reviews, those should be pretty popular movies!
print(movies.set_index('movieId').loc[dftmp.index[dftmp.num_ratings>n]]['title'])
# Let's check the average rating too, those should be pretty good movies!
rating.set_index('movieId').loc[dftmp.index[dftmp.num_ratings>n]].groupby('movieId').mean().rating.plot(style='o')
plt.ylabel('Average rating')
plt.title('Most popular movies rating')
plt.show()
# Out:
# movieId
# 1                                        Toy Story (1995)
# 47                            Seven (a.k.a. Se7en) (1995)
# 50                             Usual Suspects, The (1995)
# 110                                     Braveheart (1995)
# 150                                      Apollo 13 (1995)
# 260             Star Wars: Episode IV - A New Hope (1977)
# 296                                   Pulp Fiction (1994)
# 318                      Shawshank Redemption, The (1994)
# 356                                   Forrest Gump (1994)
# 480                                  Jurassic Park (1993)
# 527                               Schindler's List (1993)
# 589                     Terminator 2: Judgment Day (1991)
# 593                      Silence of the Lambs, The (1991)
# 780                  Independence Day (a.k.a. ID4) (1996)
# 1196    Star Wars: Episode V - The Empire Strikes Back...
# 2571                                   Matrix, The (1999)
# 2858                               American Beauty (1999)
# 2959                                    Fight Club (1999)
# Name: title, dtype: object

# %%
# Which is the best most popular movie ever??
tmp = rating.set_index('movieId').loc[dftmp.index[dftmp.num_ratings>n]].groupby('movieId').mean()
best = movies.set_index('movieId').loc[tmp.rating.idxmax].title
print ('Best most popular movie ever is...%s' %best)
# Out:
# Best most popular movie ever is...Shawshank Redemption, The (1994)

# %% [markdown]
# ### Reglas de asociación basada en películas
#
# - Item: Peliculas vistas por un usuario
# - I: todas las peliculas vistas por los usuarios
# - Transacción: peliculas vistas por cada usuario

# %%
shrt_data_userId_ord=df.sort_values( by='userId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
shrt_data_userId_ord.head()
# Out:
#        userId  movieId  rating                       title  \
# 0           1        1     4.0            Toy Story (1995)
# 12117       1     2389     2.0               Psycho (1998)
# 12126       1     2395     5.0             Rushmore (1998)
# 12182       1     2406     4.0  Romancing the Stone (1984)
# 776         1       70     3.0  From Dusk Till Dawn (1996)
#
#                                             genres  year            only_title
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995            Toy Story
# 12117                        Crime|Horror|Thriller  1998               Psycho
# 12126                                 Comedy|Drama  1998             Rushmore
# 12182              Action|Adventure|Comedy|Romance  1984  Romancing the Stone
# 776                  Action|Comedy|Horror|Thriller  1996  From Dusk Till Dawn

# %%
srtdr=shrt_data_userId_ord.values[:,[0,6]]
print(srtdr)
# Out:
# [[1 'Toy Story ']
#  [1 'Psycho ']
#  [1 'Rushmore ']
#  ...
#  [610 'Coraline ']
#  [610 'Serious Man, A ']
#  [610 '31 ']]

# %%
transactions=[]
for title, userId  in groupby(srtdr, lambda x: x[0]):
    transactions.append([item[1] for item in  userId])
print(transactions)
# Out:
# [['Toy Story ', 'Psycho ', 'Rushmore ', 'Romancing the Stone ', 'From Dusk Till Dawn ', 'Young Sherlock Holmes ', 'Thin Red Line, The ', 'Howard the Duck ', 'Texas Chainsaw Massacre, The ', 'Crocodile Dundee ', '¡Three Amigos! ', '20 Dates ', 'Very Bad Things ', 'Office Space ', 'Planet of the Apes ', 'Lock, Stock & Two Smoking Barrels ', 'Matrix, The ', 'Go ', 'SLC Punk! ', 'Dick Tracy ', 'Mummy, The ', 'Star Wars: Episode I - The Phantom Menace ', 'Superman ', 'Superman II ', 'Dracula ', "Logan's Run ", 'King Kong ', 'Enemy of the State ', 'I Still Know What You Did Last Summer ', 'Flight of the Navigator ', 'Great Mouse Detective, The ', 'Honey, I Shrunk the Kids ', 'Negotiator, The ', 'Jungle Book, The ', 'Rescuers, The ', 'Return to Oz ', 'Rocketeer, The ', 'Sleeping Beauty ', 'Song of the South ', 'Tron ', 'Indiana Jones and the Temple of Doom ', 'Lord of the Rings, The ', "Charlotte's Web ", 'Secret of NIMH, The ', 'American Tail, An ', 'Legend ', 'NeverEnding Story, The ', 'Beetlejuice ', 'Willow ', 'Toys ', 'Few Good Men, A ', 'Rush Hour ', 'Edward Scissorhands ', 'American History X ', 'Frankenstein ', 'Wolf Man, The ', 'Rocky Horror Picture Show, The ', 'Run Lola Run (Lola rennt) ', "Wayne's World ", 'Scream 3 ', 'JFK ', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze ', 'Teenage Mutant Ninja Turtles III ', 'Red Dawn ', 'Good Morning, Vietnam ', 'Grumpy Old Men ', 'Ladyhawke ', 'Hook ', 'Predator ', 'Gladiator ', 'Road Trip ', 'Man with the Golden Gun, The ', 'Blazing Saddles ', 'Mad Max ', 'Road Warrior, The (Mad Max 2) ', 'Shaft ', 'Big Trouble in Little China ', 'Shaft ', 'X-Men ', 'What About Bob? ', 'Transformers: The Movie ', 'M*A*S*H (a.k.a. MASH) ', 'Usual Suspects, The ', 'Sister Act ', 'Black Cauldron, The ', 'Encino Man ', 'Easy Rider ', 'South Park: Bigger, Longer and Uncut ', 'Ghostbusters (a.k.a. Ghost Busters) ', 'Iron Giant, The ', 'Big ', '13th Warrior, The ', 'American Beauty ', 'Excalibur ', "Gulliver's Travels ", 'Total Recall ', 'Dirty Dozen, The ', 'Goldfinger ', 'From Russia with Love ', 'Dr. No ', 'Fight Club ', 'RoboCop ', 'Who Framed Roger Rabbit? ', 'Live and Let Die ', 'Thunderball ', 'Being John Malkovich ', 'Spaceballs ', 'Robin Hood ', 'Dogma ', 'Messenger: The Story of Joan of Arc, The ', 'Longest Day, The ', 'Green Mile, The ', 'Talented Mr. Ripley, The ', 'Saving Private Ryan ', 'Bambi ', 'Back to the Future Part III ', 'James and the Giant Peach ', 'Space Jam ', 'Rock, The ', 'Twister ', 'Independence Day (a.k.a. ID4) ', "She's the One ", 'Wizard of Oz, The ', 'Citizen Kane ', 'Adventures of Robin Hood, The ', 'Ghost and Mrs. Muir, The ', 'Mr. Smith Goes to Washington ', 'Escape to Witch Mountain ', 'Winnie the Pooh and the Blustery Day ', 'Three Caballeros, The ', 'Sword in the Stone, The ', 'Dumbo ', "Pete's Dragon ", 'Bedknobs and Broomsticks ', 'Alice in Wonderland ', 'That Thing You Do! ', 'Ghost and the Darkness, The ', 'Swingers ', 'Willy Wonka & the Chocolate Factory ', "Monty Python's Life of Brian ", 'Reservoir Dogs ', 'Mission: Impossible ', 'Platoon ', 'Fargo ', 'Silence of the Lambs, The ', 'Canadian Bacon ', 'Desperado ', 'Billy Madison ', 'Clerks ', 'Dumb & Dumber (Dumb and Dumber) ', 'Ed Wood ', 'Star Wars: Episode IV - A New Hope ', 'Pulp Fiction ', 'Stargate ', 'Tommy Boy ', 'Clear and Present Danger ', 'Forrest Gump ', 'Jungle Book, The ', 'Mask, The ', 'Blown Away ', 'Dazed and Confused ', 'Fugitive, The ', 'Jurassic Park ', 'Mrs. Doubtfire ', "Schindler's List ", 'So I Married an Axe Murderer ', 'Three Musketeers, The ', 'Tombstone ', 'Dances with Wolves ', 'Batman ', 'Pinocchio ', 'Seven (a.k.a. Se7en) ', 'Basic Instinct ', 'Abyss, The ', 'Braveheart ', 'Best Men ', 'Grosse Pointe Blank ', 'Austin Powers: International Man of Mystery ', 'Con Air ', 'Face/Off ', 'Men in Black (a.k.a. MIB) ', 'Conan the Barbarian ', 'L.A. Confidential ', 'Kiss the Girls ', 'Game, The ', 'I Know What You Did Last Summer ', 'Starship Troopers ', 'Big Lebowski, The ', 'Wed ...

# %%
#min_support y min_confiden entre 0 y 1  
itemsets, rules = apriori(transactions, min_support=0.3,  min_confidence=0.3)
itemsets, rules
# Out:
# ({1: {('Aladdin ',): 183,
#    ('American Beauty ',): 204,
#    ('Apollo 13 ',): 201,
#    ('Batman ',): 189,
#    ('Braveheart ',): 237,
#    ('Fight Club ',): 218,
#    ('Forrest Gump ',): 329,
#    ('Fugitive, The ',): 190,
#    ('Godfather, The ',): 192,
#    ('Independence Day (a.k.a. ID4) ',): 202,
#    ('Jurassic Park ',): 238,
#    ('Lord of the Rings: The Fellowship of the Ring, The ',): 198,
#    ('Lord of the Rings: The Return of the King, The ',): 185,
#    ('Lord of the Rings: The Two Towers, The ',): 188,
#    ('Matrix, The ',): 278,
#    ('Pulp Fiction ',): 307,
#    ('Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) ',): 200,
#    ('Saving Private Ryan ',): 188,
#    ("Schindler's List ",): 220,
#    ('Seven (a.k.a. Se7en) ',): 203,
#    ('Shawshank Redemption, The ',): 317,
#    ('Silence of the Lambs, The ',): 279,
#    ('Star Wars: Episode IV - A New Hope ',): 251,
#    ('Star Wars: Episode V - The Empire Strikes Back ',): 211,
#    ('Star Wars: Episode VI - Return of the Jedi ',): 196,
#    ('Terminator 2: Judgment Day ',): 224,
#    ('Toy Story ',): 215,
#    ('Usual Suspects, The ',): 204},
#   2: {('Braveheart ', 'Forrest Gump '): 183,
#    ('Forrest Gump ', 'Jurassic Park '): 198,
#    ('Forrest Gump ', 'Matrix, The '): 194,
#    ('Forrest Gump ', 'Pulp Fiction '): 230,
#    ('Forrest Gump ', 'Shawshank Redemption, The '): 231,
#    ('Forrest Gump ', 'Silence of the Lambs, The '): 199,
#    ('Matrix, The ', 'Star Wars: Episode IV - A New Hope '): 183,
#    ('Pulp Fiction ', 'Shawshank Redemption, The '): 222,
#    ('Pulp Fiction ', 'Silence of the Lambs, The '): 207,
#    ('Shawshank Redemption, The ', 'Silence of the Lambs, The '): 199,
#    ('Star Wars: Episode IV - A New Hope ',
#     'Star Wars: Episode V - The Empire Strikes Back '): 190}},
#  [{Forrest Gump } -> {Braveheart },
#   {Braveheart } -> {Forrest Gump },
#   {Jurassic Park } -> {Forrest Gump },
#   {Forrest Gump } -> {Jurassic Park },
#   {Matrix, The } -> {Forrest Gump },
#   {Forrest Gump } -> {Matrix, The },
#   {Pulp Fiction } -> {Forrest Gump },
#   {Forrest Gump } -> {Pulp Fiction },
#   {Shawshank Redemption, The } -> {Forrest Gump },
#   {Forrest Gump } -> {Shawshank Redemption, The },
#   {Silence of the Lambs, The } -> {Forrest Gump },
#   {Forrest Gump } -> {Silence of the Lambs, The },
#   {Star Wars: Episode IV - A New Hope } -> {Matrix, The },
#   {Matrix, The } -> {Star Wars: Episode IV - A New Hope },
#   {Shawshank Redemption, The } -> {Pulp Fiction },
#   {Pulp Fiction } -> {Shawshank Redemption, The },
#   {Silence of the Lambs, The } -> {Pulp Fiction },
#   {Pulp Fiction } -> {Silence of the Lambs, The },
#   {Silence of the Lambs, The } -> {Shawshank Redemption, The },
#   {Shawshank Redemption, The } -> {Silence of the Lambs, The },
#   {Star Wars: Episode V - The Empire Strikes Back } -> {Star Wars: Episode IV - A New Hope },
#   {Star Wars: Episode IV - A New Hope } -> {Star Wars: Episode V - The Empire Strikes Back }])

# %%
rules=sorted(rules, key=lambda rule: rule.confidence)
for rule in rules:
  print(rule) # Prints the rule and its confidence, support, lift, ...
# Out:
# {Forrest Gump } -> {Braveheart } (conf: 0.556, supp: 0.300, lift: 1.432, conv: 1.378)
# {Forrest Gump } -> {Matrix, The } (conf: 0.590, supp: 0.318, lift: 1.294, conv: 1.326)
# {Forrest Gump } -> {Jurassic Park } (conf: 0.602, supp: 0.325, lift: 1.542, conv: 1.532)
# {Forrest Gump } -> {Silence of the Lambs, The } (conf: 0.605, supp: 0.326, lift: 1.322, conv: 1.373)
# {Shawshank Redemption, The } -> {Silence of the Lambs, The } (conf: 0.628, supp: 0.326, lift: 1.373, conv: 1.458)
# {Matrix, The } -> {Star Wars: Episode IV - A New Hope } (conf: 0.658, supp: 0.300, lift: 1.600, conv: 1.722)
# {Pulp Fiction } -> {Silence of the Lambs, The } (conf: 0.674, supp: 0.339, lift: 1.474, conv: 1.666)
# {Matrix, The } -> {Forrest Gump } (conf: 0.698, supp: 0.318, lift: 1.294, conv: 1.525)
# {Forrest Gump } -> {Pulp Fiction } (conf: 0.699, supp: 0.377, lift: 1.389, conv: 1.651)
# {Shawshank Redemption, The } -> {Pulp Fiction } (conf: 0.700, supp: 0.364, lift: 1.392, conv: 1.657)
# {Forrest Gump } -> {Shawshank Redemption, The } (conf: 0.702, supp: 0.379, lift: 1.351, conv: 1.613)
# {Silence of the Lambs, The } -> {Forrest Gump } (conf: 0.713, supp: 0.326, lift: 1.322, conv: 1.607)
# {Silence of the Lambs, The } -> {Shawshank Redemption, The } (conf: 0.713, supp: 0.326, lift: 1.373, conv: 1.675)
# {Pulp Fiction } -> {Shawshank Redemption, The } (conf: 0.723, supp: 0.364, lift: 1.392, conv: 1.735)
# {Shawshank Redemption, The } -> {Forrest Gump } (conf: 0.729, supp: 0.379, lift: 1.351, conv: 1.698)
# {Star Wars: Episode IV - A New Hope } -> {Matrix, The } (conf: 0.729, supp: 0.300, lift: 1.600, conv: 2.009)
# {Silence of the Lambs, The } -> {Pulp Fiction } (conf: 0.742, supp: 0.339, lift: 1.474, conv: 1.925)
# {Pulp Fiction } -> {Forrest Gump } (conf: 0.749, supp: 0.377, lift: 1.389, conv: 1.837)
# {Star Wars: Episode IV - A New Hope } -> {Star Wars: Episode V - The Empire Strikes Back } (conf: 0.757, supp: 0.311, lift: 2.188, conv: 2.691)
# {Braveheart } -> {Forrest Gump } (conf: 0.772, supp: 0.300, lift: 1.432, conv: 2.022)
# {Jurassic Park } -> {Forrest Gump } (conf: 0.832, supp: 0.325, lift: 1.542, conv: 2.741)
# {Star Wars: Episode V - The Empire Strikes Back } -> {Star Wars: Episode IV - A New Hope } (conf: 0.900, supp: 0.311, lift: 2.188, conv: 5.913)
