# %% [markdown]
# Integrantes:
#
# - Nahir Trógolo
# - Lucia Benitez
# - Johanna Frau

# %%
import numpy as np
import pandas as pd

from efficient_apriori import apriori
from itertools import combinations, groupby

# %%
movies = pd.read_csv('movies.csv')
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
movies.sample(5)
# Out:
#        movieId                                 title                  genres
# 934        951                His Girl Friday (1940)          Comedy|Romance
# 6815      6927               Human Stain, The (2003)  Drama|Romance|Thriller
# 18042    90432                         Lentsu (1990)                  Comedy
# 15051    76171                 India (Indien) (1993)            Comedy|Drama
# 22044   106232  Reformer and the Redhead, The (1950)          Comedy|Romance

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB

# %% [markdown]
# El dataset de movies tiene 3 columnas de features:
#
# - Identificador de Películas (movieId)
# - Título de la película junto con el año de lanzamiento (title)
# - Géneros a los cuales pertenece la película (genres).

# %%
new_movies = movies
new_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Preparación de los datos
#
# ### Creación de la columna year

# %% [markdown]
# Ahora crearemos una nueva columna que contenga sólo el año de las películas.

# %%
new_movies['year'] = new_movies['title'].str.rsplit(')',1).str[0].str.rsplit('(',1).str[1]
new_movies['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
# 5        1995
# 6        1995
# 7        1995
# 8        1995
# 9        1995
# 10       1995
# 11       1995
# 12       1995
# 13       1995
# 14       1995
# 15       1995
# 16       1995
# 17       1995
# 18       1995
# 19       1995
# 20       1995
# 21       1995
# 22       1995
# 23       1995
# 24       1995
# 25       1995
# 26       1995
# 27       1995
# 28       1995
# 29       1995
#          ...
# 27248    1999
# 27249    2011
# 27250    2006
# 27251    1966
# 27252    1999
# 27253    2002
# 27254    1991
# 27255    2009
# 27256    2014
# 27257    2011
# 27258    2009
# 27259    2014
# 27260    2015
# 27261    2013
# 27262    2014
# 27263    2014
# 27264    2015
# 27265    2014
# 27266    2010
# 27267    2011
# 27268    2000
# 27269    2003
# 27270    2006
# 27271    2000
# 27272    2001
# 27273    2007
# 27274    2002
# 27275    2014
# 27276    2001
# 27277    2014
# Name: year, Length: 27278, dtype: object

# %% [markdown]
# Veamos si dicha columna quedó bien chequeando los valores únicos.

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1988', '1967', '1993',
#        '1964', '1977', '1965', '1982', '1985', '1990', '1991', '1989',
#        '1937', '1940', '1969', '1981', '1973', '1970', '1960', '1955',
#        '1959', '1968', '1980', '1975', '1986', '1948', '1943', '1950',
#        '1946', '1987', '1997', '1974', '1956', '1958', '1949', '1972',
#        '1998', '1933', '1952', '1951', '1957', '1961', '1954', '1934',
#        '1944', '1963', '1942', '1941', '1953', '1939', '1947', '1945',
#        '1938', '1935', '1936', '1926', '1932', '1979', '1971', '1978',
#        '1966', '1962', '1983', '1984', '1931', '1922', '1999', '1927',
#        '1929', '1930', '1928', '1925', '1914', '2000', '1919', '1923',
#        '1920', '1918', '1921', '2001', '1924', '2002', '2003', '1915',
#        '2004', '1916', '1917', '2005', '2006', '1902', nan, '1903',
#        '2007', '2008', '2009', '1912', '2010', 'Das Millionenspiel',
#        '1913', '2011', '1898', '1899', 'Bicicleta, cullera, poma', '1894',
#        '2012', '1909', '1910', '1901', '1893', '2013', '1896', '1983)',
#        '2014', '2009– ', '2007-', '1975-1979', '1895', '2015', '1900',
#        '1905', '1891'], dtype=object)

# %% [markdown]
# Observamos que dado que hay películas que no tienen el año de lanzamiento la columna 'year' contiene algunos valores que no son numéricos. Chequearemos si estos valores son pocos con respecto a la cantidad total y en dicho caso procederemos a eliminarlos de este análisis.
#
# Los valores a chequear son:
#
# - Das Millionenspiel
# - Bicicleta, cullera, poma
# - 2009–
# - 2007-
# - 1983)
# - 1975-1979
#
# y las columnas de los valores nulos.

# %%
new_movies[new_movies['year']=='Bicicleta, cullera, poma']
# Out:
#        movieId                                             title       genres  \
# 17341    87442  Bicycle, Spoon, Apple (Bicicleta, cullera, poma)  Documentary
#
#                            year
# 17341  Bicicleta, cullera, poma

# %%
new_movies[new_movies['year']=='Das Millionenspiel']
# Out:
#        movieId                                    title  \
# 15646    79607  Millions Game, The (Das Millionenspiel)
#
#                              genres                year
# 15646  Action|Drama|Sci-Fi|Thriller  Das Millionenspiel

# %%
new_movies[new_movies['year']=='1975-1979']
# Out:
#        movieId                      title  genres       year
# 22679   108583  Fawlty Towers (1975-1979)  Comedy  1975-1979

# %% [markdown]
# Procedemos a declarar estos índices como 'no year'.

# %%
new_movies.at[17341, 'year'] = 'no year'
new_movies.at[15646, 'year'] = 'no year'
new_movies.at[22679, 'year'] = 'no year'

# %% [markdown]
# Veamos que pasa con 2009–  y 2007-

# %%
new_movies[new_movies['year']=='2009– ']
# Out:
#        movieId                         title  genres    year
# 22368   107434  Diplomatic Immunity (2009– )  Comedy  2009–

# %%
new_movies[new_movies['year']=='2007-']
# Out:
#        movieId                         title  genres   year
# 22669   108548  Big Bang Theory, The (2007-)  Comedy  2007-

# %%
new_movies[new_movies['year']=='1983)']
# Out:
#        movieId                                              title genres  \
# 19859    98063  Mona and the Time of Burning Love (Mona ja pal...  Drama
#
#         year
# 19859  1983)

# %% [markdown]
# Corregimos esos valores.

# %%
new_movies.at[22368, 'year'] = '2009'

# %%
new_movies.at[22669, 'year'] = '2007'

# %%
new_movies.at[19859, 'year'] = '1983'

# %% [markdown]
# Chequeamos nuevamente los valores únicos en la columna year.

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1988', '1967', '1993',
#        '1964', '1977', '1965', '1982', '1985', '1990', '1991', '1989',
#        '1937', '1940', '1969', '1981', '1973', '1970', '1960', '1955',
#        '1959', '1968', '1980', '1975', '1986', '1948', '1943', '1950',
#        '1946', '1987', '1997', '1974', '1956', '1958', '1949', '1972',
#        '1998', '1933', '1952', '1951', '1957', '1961', '1954', '1934',
#        '1944', '1963', '1942', '1941', '1953', '1939', '1947', '1945',
#        '1938', '1935', '1936', '1926', '1932', '1979', '1971', '1978',
#        '1966', '1962', '1983', '1984', '1931', '1922', '1999', '1927',
#        '1929', '1930', '1928', '1925', '1914', '2000', '1919', '1923',
#        '1920', '1918', '1921', '2001', '1924', '2002', '2003', '1915',
#        '2004', '1916', '1917', '2005', '2006', '1902', nan, '1903',
#        '2007', '2008', '2009', '1912', '2010', 'no year', '1913', '2011',
#        '1898', '1899', '1894', '2012', '1909', '1910', '1901', '1893',
#        '2013', '1896', '2014', '1895', '2015', '1900', '1905', '1891'],
#       dtype=object)

# %% [markdown]
# En las filas con valores nulos colocamos la categoría "no year".

# %%
year_null = new_movies[new_movies['year'].isnull()]

# %%
index_year_null = np.array(year_null.index)
index_year_null
# Out:
# array([10593, 23617, 23824, 24286, 24412, 26115, 26127, 26180, 26335,
#        26395, 26432, 26749, 26784, 26963, 26974, 27027, 27114])

# %%
new_movies.at[index_year_null, 'year'] = 'no year'

# %%
new_movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1988', '1967', '1993',
#        '1964', '1977', '1965', '1982', '1985', '1990', '1991', '1989',
#        '1937', '1940', '1969', '1981', '1973', '1970', '1960', '1955',
#        '1959', '1968', '1980', '1975', '1986', '1948', '1943', '1950',
#        '1946', '1987', '1997', '1974', '1956', '1958', '1949', '1972',
#        '1998', '1933', '1952', '1951', '1957', '1961', '1954', '1934',
#        '1944', '1963', '1942', '1941', '1953', '1939', '1947', '1945',
#        '1938', '1935', '1936', '1926', '1932', '1979', '1971', '1978',
#        '1966', '1962', '1983', '1984', '1931', '1922', '1999', '1927',
#        '1929', '1930', '1928', '1925', '1914', '2000', '1919', '1923',
#        '1920', '1918', '1921', '2001', '1924', '2002', '2003', '1915',
#        '2004', '1916', '1917', '2005', '2006', '1902', 'no year', '1903',
#        '2007', '2008', '2009', '1912', '2010', '1913', '2011', '1898',
#        '1899', '1894', '2012', '1909', '1910', '1901', '1893', '2013',
#        '1896', '2014', '1895', '2015', '1900', '1905', '1891'],
#       dtype=object)

# %%
new_movies.sample(20)
# Out:
#        movieId                                              title  \
# 25958   123645                       A Lesson Before Dying (1999)
# 25454   120448                                    Geronimo (1962)
# 14023    70366           Silent Night, Deadly Night Part 2 (1987)
# 7658      8126                              Shock Corridor (1963)
# 13287    65133                     Blackadder Back & Forth (1999)
# 16039    81184             Short Film About John Bolton, A (2003)
# 3358      3447                             Good Earth, The (1937)
# 25590   121029                     No Distance Left to Run (2010)
# 1778      1861                    Junk Mail (Budbringeren) (1997)
# 14899    74613      Therese Raquin (a.k.a. Adultress, The) (1953)
# 22870   109353                         Meet Me at the Fair (1953)
# 8896     26520  Full Moon in Paris (Les nuits de la pleine lun...
# 11823    52712                              Invisible, The (2007)
# 5222      5319                  Nine Queens (Nueve reinas) (2000)
# 6788      6898                               Sweet Sixteen (2002)
# 19858    98061                                      Himizu (2011)
# 23564   112204                                Bitter Creek (1954)
# 26438   127017                 The Man They Could Not Hang (1939)
# 24318   115240                                    Land Ho! (2014)
# 19840    98007                                  Miehen tie (1940)
#
#                                      genres  year
# 25958                                 Drama  1999
# 25454                        Action|Western  1962
# 14023                         Comedy|Horror  1987
# 7658                                  Drama  1963
# 13287                                Comedy  1999
# 16039                Fantasy|Horror|Mystery  2003
# 3358                                  Drama  1937
# 25590                           Documentary  2010
# 1778                        Comedy|Thriller  1997
# 14899                   Crime|Drama|Romance  1953
# 22870                               Musical  1953
# 8896                          Drama|Romance  1984
# 11823  Crime|Drama|Fantasy|Mystery|Thriller  2007
# 5222                         Crime|Thriller  2000
# 6788                                  Drama  2002
# 19858                  Children|Crime|Drama  2011
# 23564                               Western  1954
# 26438                   Crime|Horror|Sci-Fi  1939
# 24318                Adventure|Comedy|Drama  2014
# 19840                                 Drama  1940

# %% [markdown]
# ### Creación de la columna con sólo el título

# %%
new_movies['only_title'] = new_movies['title'].str.rsplit('(',1).str[0]
new_movies.sample(50)
# Out:
#        movieId                                              title  \
# 13498    66762                                       Paris (2008)
# 18314    91533                                       Dacii (1967)
# 17304    87306                                     Super 8 (2011)
# 17947    90035                      Report, The (Gozaresh) (1977)
# 23933   113634  Message from Akira Kurosawa: For Beautiful Mov...
# 11455    49280                                       Bobby (2006)
# 16174    81765  Playing from the Plate (Grajacy z talerza) (1995)
# 20040    98795                                        Jazz (2001)
# 25487   120627                             The Disappeared (2008)
# 10506    39381                            Proposition, The (2005)
# 5652      5751                            Goodbye Pork Pie (1981)
# 9054     26788    Story of Qiu Ju, The (Qiu Ju da guan si) (1992)
# 22955   109635                           Pandora's Promise (2013)
# 2691      2777                                       Cobra (1925)
# 4210      4305                                  Angel Eyes (2001)
# 24297   115164                            Good For Nothing (2011)
# 12890    60937      Mummy: Tomb of the Dragon Emperor, The (2008)
# 5234      5331                                      Vulgar (2000)
# 727        739                      Honey Moon (Honigmond) (1996)
# 9070     26814                      Cyborg 2: Glass Shadow (1993)
# 7287      7399                                   Ned Kelly (1970)
# 18014    90327                           Bullfighters, The (1945)
# 1308      1337                          Body Snatcher, The (1945)
# 22410   107612                      WNUF Halloween Special (2013)
# 16756    84730            Army of Crime (L'armée du crime) (2009)
# 779        792  Hungarian Fairy Tale, A (Hol volt, hol nem vol...
# 4332      4427                         Lion in Winter, The (1968)
# 6477      6587                                       Gigli (2003)
# 25637   121205                                  Nine Lives (2002)
# 6397      6507                  Just a Little Harmless Sex (1999)
# 16033    81158                                    Restrepo (2010)
# 23552   112138                              22 Jump Street (2014)
# 2679      2765                             Acid House, The (1998)
# 10045    33126                             Frisco Kid, The (1979)
# 12122    55199                             Contractor, The (2007)
# 15429    78649                          Hot Dog Program, A (1999)
# 14355    71926                          Boys Are Back, The (2009)
# 24928   117690                                 Enchantment (1948)
# 25871   122849                              Naked Violence (1969)
# 22369   107436                                     Haunter (2013)
# 8365     25768                              Sadie Thompson (1928)
# 11976    54010                               Bedtime Story (1964)
# 19994    98528              Paramore Live, the Final Riot! (2008)
# 14491    72601  Teenage Mutant Ninja Turtles: Turtles Forever ...
# 23277   110796                                 Le Week-End (2013)
# 12853    60654  Last Mistress, The (vieille maîtresse, Une) (2...
# 6961      7073                         Shot in the Dark, A (1964)
# 5192      5289                               Body and Soul (1947)
# 1210      1237    Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 12291    56548                           All Passion Spent (1986)
#
#                                            genres  year  \
# 13498                        Comedy|Drama|Romance  2008
# 18314                                   Drama|War  1967
# 17304                Mystery|Sci-Fi|Thriller|IMAX  2011
# 17947                                       Drama  1977
# 23933                                 Documentary  2000
# 11455                                       Drama  2006
# 16174                       Drama|Fantasy|Mystery  1995
# 20040                                 Documentary  2001
# 25487                                 Documentary  2008
# 10506                         Crime|Drama|Western  2005
# 5652                       Action|Adventure|Drama  1981
# 9054                                 Comedy|Drama  1992
# 22955                                 Documentary  2013
# 2691                                        Drama  1925
# 4210                             Romance|Thriller  2001
# 24297                              Comedy|Western  2011
# 12890           Action|Adventure|Fantasy|Thriller  2008
# 5234                                        Drama  2000
# 727                                        Comedy  1996
# 9070                       Action|Sci-Fi|Thriller  1993
# 7287                         Action|Crime|Western  1970
# 18014                              Comedy|Musical  1945
# 1308                        Drama|Horror|Thriller  1945
# 22410                               Comedy|Horror  2013
# 16756                          Drama|Thriller|War  2009
# 779                                       Fantasy  1987
# 4332                                        Drama  1968
# 6477                         Comedy|Crime|Romance  2003
# 25637                             Horror|Thriller  2002
# 6397                               Comedy|Romance  1999
# 16033                             Documentary|War  2010
# 23552                         Action|Comedy|Crime  2014
# 2679                                 Comedy|Drama  1998
# 10045                              Comedy|Western  1979
# 12122                       Action|Drama|Thriller  2007
# 15429                                 Documentary  1999
# 14355                                Comedy|Drama  2009
# 24928                               Drama|Romance  1948
# 25871                                 Crime|Drama  1969
# 22369                     Horror|Mystery|Thriller  2013
# 8365                                        Drama  1928
# 11976                                      Comedy  1964
# 19994                         Documentary|Musical  2008
# 14491  Action|Adventure|Animation|Comedy|Thriller  2009
# 23277                                Comedy|Drama  2013
# 12853                                       Drama  2007
# 6961                         Comedy|Crime|Mystery  1964
# 5192                              Drama|Film-Noir  1947
# 1210                                        Drama  1957
# 12291                                       Drama  1986
#
#                                               only_title
# 13498                                             Paris
# 18314                                             Dacii
# 17304                                           Super 8
# 17947                            Report, The (Gozaresh)
# 23933  Message from Akira Kurosawa: For Beautiful Mov...
# 11455                                             Bobby
# 16174        Playing from the Plate (Grajacy z talerza)
# 20040                                              Jazz
# 25487                                   The Disappeared
# 10506                                  Proposition, The
# 5652                                   Goodbye Pork Pie
# 9054           Story of Qiu Ju, The (Qiu Ju da guan si)
# 22955                                 Pandora's Promise
# 2691                                              Cobra
# 4210                                         Angel Eyes
# 24297                                  Good For Nothing
# 12890            Mummy: Tomb of the Dragon Emperor, The
# 5234                                             Vulgar
# 727                              Honey Moon (Honigmond)
# 9070                             Cyborg 2: Glass Shadow
# 7287                                          Ned Kelly
# 18014                                 Bullfighters, The
# 1308                                 Body Snatcher, The
# 22410                            WNUF Halloween Special
# 16756                  Army of Crime (L'armée du crime)
# 779    Hungarian Fairy Tale, A (Hol volt, hol nem volt)
# 4332                                Lion in Winter, The
# 6477                                              Gigli
# 25637                                        Nine Lives
# 6397                         Just a Little Harmless Sex
# 16033                                          Restrepo
# 23552                                    22 Jump Street
# 2679                                    Acid House, The
# 10045                                   Frisco Kid, The
# 12122                                   Contractor, The
# 15429                                Hot Dog Program, A
# 14355                                Boys Are Back, The
# 24928                                       Enchantment
# 25871                                    Naked Violence
# 22369                                           Haunter
# 8365                                     Sadie Thompson
# 11976                                     Bedtime Story
# 19994                    Paramore Live, the Final Riot!
# 14491     Teenage Mutant Ninja Turtles: Turtles Forever
# 23277                                       Le Week-End
# 12853       Last Mistress, The (vieille maîtresse, Une)
# 6961                                Shot in the Dark, A
# 5192                                      Body and Soul
# 1210           Seventh Seal, The (Sjunde inseglet, Det)
# 12291                                 All Passion Spent

# %% [markdown]
# ## Rating dataset

# %%
rating = pd.read_csv('ratings.csv')
rating.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 17718861  122523    71135     3.5  1397519517
# 7233345    49914     1201     2.5  1225726266
# 12208273   84355      260     5.0   938953745
# 17040655  117899     2605     1.0   946625533
# 46177        348    59141     4.0  1228621024

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB

# %% [markdown]
# El dataset de rating contiene 4 columnas de features:
#
# - Identificador de usuario (userId)
# - Identificador de películas (movieId)
# - Rating de la película (rating)
# - timestamp
#
# Vamos a proceder a unir los dos dataset mediante el Id de las películas.

# %%
df = pd.merge(rating,new_movies, on='movieId')

# %%
df.head(20)
# Out:
#     userId  movieId  rating   timestamp           title  \
# 0        1        2     3.5  1112486027  Jumanji (1995)
# 1        5        2     3.0   851527569  Jumanji (1995)
# 2       13        2     3.0   849082742  Jumanji (1995)
# 3       29        2     3.0   835562174  Jumanji (1995)
# 4       34        2     3.0   846509384  Jumanji (1995)
# 5       54        2     3.0   974918176  Jumanji (1995)
# 6       88        2     1.0  1098277938  Jumanji (1995)
# 7       91        2     3.5  1112061358  Jumanji (1995)
# 8      116        2     2.0  1132728068  Jumanji (1995)
# 9      119        2     4.0   845110667  Jumanji (1995)
# 10     120        2     1.0   838153425  Jumanji (1995)
# 11     124        2     2.0  1134476330  Jumanji (1995)
# 12     127        2     3.0   847127455  Jumanji (1995)
# 13     128        2     3.0   900720958  Jumanji (1995)
# 14     129        2     3.0  1283448701  Jumanji (1995)
# 15     131        2     1.0  1238326861  Jumanji (1995)
# 16     132        2     3.0  1114172997  Jumanji (1995)
# 17     137        2     3.0   992797771  Jumanji (1995)
# 18     142        2     4.0   833458658  Jumanji (1995)
# 19     152        2     3.0  1161215251  Jumanji (1995)
#
#                         genres  year only_title
# 0   Adventure|Children|Fantasy  1995   Jumanji
# 1   Adventure|Children|Fantasy  1995   Jumanji
# 2   Adventure|Children|Fantasy  1995   Jumanji
# 3   Adventure|Children|Fantasy  1995   Jumanji
# 4   Adventure|Children|Fantasy  1995   Jumanji
# 5   Adventure|Children|Fantasy  1995   Jumanji
# 6   Adventure|Children|Fantasy  1995   Jumanji
# 7   Adventure|Children|Fantasy  1995   Jumanji
# 8   Adventure|Children|Fantasy  1995   Jumanji
# 9   Adventure|Children|Fantasy  1995   Jumanji
# 10  Adventure|Children|Fantasy  1995   Jumanji
# 11  Adventure|Children|Fantasy  1995   Jumanji
# 12  Adventure|Children|Fantasy  1995   Jumanji
# 13  Adventure|Children|Fantasy  1995   Jumanji
# 14  Adventure|Children|Fantasy  1995   Jumanji
# 15  Adventure|Children|Fantasy  1995   Jumanji
# 16  Adventure|Children|Fantasy  1995   Jumanji
# 17  Adventure|Children|Fantasy  1995   Jumanji
# 18  Adventure|Children|Fantasy  1995   Jumanji
# 19  Adventure|Children|Fantasy  1995   Jumanji

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 8 columns):
# userId        int64
# movieId       int64
# rating        float64
# timestamp     int64
# title         object
# genres        object
# year          object
# only_title    object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.3+ GB

# %%
final_df = df.sample(frac= 0.01)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200003 entries, 4942547 to 15838034
# Data columns (total 8 columns):
# userId        200003 non-null int64
# movieId       200003 non-null int64
# rating        200003 non-null float64
# timestamp     200003 non-null int64
# title         200003 non-null object
# genres        200003 non-null object
# year          200003 non-null object
# only_title    200003 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 13.7+ MB

# %% [markdown]
# ### Reglas de asociación basada en películas
#
# - Item: Peliculas vistas por un usuario
# - I: todas las peliculas vistas por los usuarios
# - Transacción: peliculas vistas por cada usuario

# %%
by_movies_df = final_df.sort_values( by='userId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
by_movies_df.head()
# Out:
#          userId  movieId  rating   timestamp  \
# 4488988       3     2699     3.0   945175870
# 190505        3      223     5.0   944918444
# 4458305       3     2657     3.0   945175730
# 3756330       3     1225     3.0   944917494
# 6572160       7     1888     3.0  1011208527
#
#                                          title                        genres  \
# 4488988                   Arachnophobia (1990)                 Comedy|Horror
# 190505                           Clerks (1994)                        Comedy
# 4458305  Rocky Horror Picture Show, The (1975)  Comedy|Horror|Musical|Sci-Fi
# 3756330                         Amadeus (1984)                         Drama
# 6572160                     Hope Floats (1998)          Comedy|Drama|Romance
#
#          year                       only_title
# 4488988  1990                   Arachnophobia
# 190505   1994                          Clerks
# 4458305  1975  Rocky Horror Picture Show, The
# 3756330  1984                         Amadeus
# 6572160  1998                     Hope Floats

# %%
userId_title = by_movies_df[['userId','only_title']]
userId_title.head()
# Out:
#          userId                       only_title
# 4488988       3                   Arachnophobia
# 190505        3                          Clerks
# 4458305       3  Rocky Horror Picture Show, The
# 3756330       3                         Amadeus
# 6572160       7                     Hope Floats

# %%
userId_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200003 entries, 4488988 to 14982572
# Data columns (total 2 columns):
# userId        200003 non-null int64
# only_title    200003 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.6+ MB

# %%
userId_title['only_title'] = userId_title['only_title'].str.rstrip() #Sacamos los espacios en blanco a la derecha
# Out:
# /home/jfrau/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
userId_title[userId_title['only_title']=='Constantine']
# Out:
#          userId   only_title
# 2510923    3218  Constantine
# 2511034    6915  Constantine
# 2511119    9917  Constantine
# 2511263   14994  Constantine
# 2511373   18165  Constantine
# 2511454   20922  Constantine
# 2511458   21051  Constantine
# 2511621   25660  Constantine
# 2511644   26320  Constantine
# 2511721   28650  Constantine
# 2511832   32321  Constantine
# 2511925   35522  Constantine
# 2512022   38773  Constantine
# 2512052   39926  Constantine
# 2512068   40443  Constantine
# 2512197   44678  Constantine
# 2512222   45314  Constantine
# 2512256   46340  Constantine
# 2512312   48098  Constantine
# 2512415   50808  Constantine
# 2512525   54143  Constantine
# 2512592   56992  Constantine
# 2512753   62375  Constantine
# 2512779   63165  Constantine
# 2512850   65534  Constantine
# 2513154   74965  Constantine
# 2513315   80325  Constantine
# 2513340   81038  Constantine
# 2513604   89494  Constantine
# 2513681   92293  Constantine
# 2513787   95678  Constantine
# 2513792   95944  Constantine
# 2514085  106193  Constantine
# 2514132  108081  Constantine
# 2514170  109270  Constantine
# 2514224  111151  Constantine
# 2514642  124633  Constantine
# 2514722  127005  Constantine

# %%
grouped_df = userId_title.groupby(['userId'])
grouped_df

# %%
lst = userId_title.groupby('userId')['only_title'].apply(pd.Series.tolist).tolist()
lst
# Out:
# [['Arachnophobia', 'Clerks', 'Rocky Horror Picture Show, The', 'Amadeus'],
#  ['Hope Floats',
#   'Independence Day (a.k.a. ID4)',
#   'Riding in Cars with Boys',
#   'Six Days Seven Nights'],
#  ['Forrest Gump'],
#  ['Bad Education (La mala educación)',
#   'Toy Story 2',
#   'Professional, The (Le professionnel)',
#   'War of the Worlds',
#   'Ratatouille',
#   'Ghost in the Shell (Kôkaku kidôtai)',
#   'Last King of Scotland, The'],
#  ['Forrest Gump'],
#  ['Mrs. Doubtfire'],
#  ['Galaxy Quest'],
#  ['Grosse Pointe Blank', 'House Party'],
#  ['Superman II', 'Sea Inside, The (Mar adentro)'],
#  ['Dangerous Beauty',
#   'Godfather, The',
#   'Good Will Hunting',
#   'Green Mile, The'],
#  ['What Women Want', 'Seven (a.k.a. Se7en)'],
#  ['Emma', "Muriel's Wedding"],
#  ['Shawshank Redemption, The',
#   'Grumpy Old Men',
#   'Pi',
#   'Lethal Weapon 4',
#   'Shining, The',
#   'Miss Congeniality'],
#  ['Austin Powers: The Spy Who Shagged Me'],
#  ['Accidental Tourist, The'],
#  ['Outbreak'],
#  ['Tommy Boy'],
#  ['Aeon Flux', 'Frozen', 'Rambo (Rambo 4)'],
#  ['Lethal Weapon'],
#  ['King Kong',
#   'Resident Evil: Extinction',
#   'Being John Malkovich',
#   'Walk the Line',
#   'Muppet Treasure Island'],
#  ['Star Wars: Episode IV - A New Hope'],
#  ['Wings of Desire (Himmel über Berlin, Der)'],
#  ['Rainmaker, The'],
#  ['Flintstones, The'],
#  ['Star Wars: Episode IV - A New Hope'],
#  ['Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)',
#   "Bridget Jones's Diary"],
#  ['Planes, Trains & Automobiles'],
#  ['Short Cuts'],
#  ['Silence of the Lambs, The'],
#  ['Alien', "National Lampoon's Vacation", 'Stand by Me'],
#  ['Simple Plan, A', 'Truman Show, The'],
#  ['Double Jeopardy',
#   'Twister',
#   'Fast Times at Ridgemont High',
#   'Sleepless in Seattle',
#   'Flashdance',
#   'Lawrence of Arabia',
#   'Garbage Pail Kids Movie, The',
#   'Living Daylights, The',
#   'Birds, The'],
#  ['High Fidelity', 'Game, The'],
#  ['Runaway Train', 'Texas Chainsaw Massacre, The', 'Amadeus'],
#  ['Little Women', 'Pulp Fiction'],
#  ['Lion King, The'],
#  ['Star Wars: Episode VI - Return of the Jedi', 'Get Shorty'],
#  ['Three Colors: White (Trzy kolory: Bialy)', 'From Dusk Till Dawn'],
#  ['Half Baked'],
#  ['Gravity'],
#  ['Hud', 'Georgia', 'Last Detail, The', 'Tea with Mussolini'],
#  ['Rear Window',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Graduate, The'],
#  ['Murder in the First'],
#  ['Network'],
#  ['Ransom', 'Bourne Supremacy, The', 'Ong-Bak: The Thai Warrior (Ong Bak)'],
#  ['Full Monty, The', 'Man on the Moon'],
#  ['Enemy at the Gates', 'Meet the Parents'],
#  ['Mask, The'],
#  ['Game, The',
#   'The Butterfly Effect',
#   "Bug's Life, A",
#   'Lethal Weapon 2',
#   'Gallipoli',
#   "Emperor's New Groove, The",
#   'Traffic',
#   "Muriel's Wedding",
#   'Good Will Hunting'],
#  ['Tomorrow Never Dies'],
#  ['Despicable Me',
#   'Primer',
#   'Bridesmaids',
#   'Total Recall',
#   '300',
#   "Howl's Moving Castle (Hauru no ugoku shiro)",
#   'Secret of NIMH, The'],
#  ['Sleepless in Seattle'],
#  ['Forrest Gump'],
#  ['Clueless'],
#  ['Cliffhanger', 'Clueless'],
#  ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ['Someone Like You', 'Rugrats Go Wild!', 'Armageddon'],
#  ['Midnight Cowboy',
#   'Piano, The',
#   'Otello',
#   'Freeway',
#   'Thin Man, The',
#   'Rosencrantz and Guildenstern Are Dead',
#   'Shall We Dance? (Shall We Dansu?)',
#   'Raging Bull'],
#  ['Weird Science', 'Bronx Tale, A'],
#  ['That Thing You Do!',
#   'Christmas Story, A',
#   '101 Dalmatians (One Hundred and One Dalmatians)',
#   "Schindler's List"],
#  ['40-Year-Old Virgin, The'],
#  ['Shakespeare in Love'],
#  ['Ed', 'Michael'],
#  ['Royal Tenenbaums, The', "Amelie (Fabuleux destin d'Amélie Poulain, Le)"],
#  ['Outbreak',
#   'Fifth Element, The',
#   'Very Brady Sequel, A',
#   'Tommy',
#   'Police Academy: Mission to Moscow',
#   'Lara Croft: Tomb Raider',
#   "Wayne's World",
#   'Drop Zone',
#   'Dave',
#   'Finding Nemo',
#   '8 Heads in a Duffel Bag',
#   'Rescuers Down Under, The'],
#  ['Ransom'],
#  ['Forrest Gump'],
#  ['Philadelphia'],
#  ['Philadelphia',
#   'Tootsie',
#   'Long Kiss Goodnight, The',
#   'Apollo 13',
#   'Subway',
#   'Broken Arrow'],
#  ['Homeward Bound: The Incredible Journey',
#   'Cube 2: Hypercube',
#   'Toy Story 3'],
#  ['Star Wars: Episode V - The Empire Strikes Back', 'Substitute, The'],
#  ['Toy Story 2'],
#  ['Psycho', 'Thelma & Louise', 'Bourne Identity, The', 'Raising Arizona'],
#  ['Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom)',
#   'Hangover, The',
#   'Definitely, Maybe'],
#  ['He Got Game',
#   'Election',
#   'Chinatown',
#   'Blues Brothers, The',
#   'Bad Boys',
#   'Rocky IV',
#   'Daytrippers, The',
#   'Rounders'],
#  ['G.I. Jane', 'Moulin Rouge', 'Chicken Run', 'Snake Eyes'],
#  ['Titanic'],
#  ['Down to Earth'],
#  ['Welcome to the Dollhouse', "Monty Python's Life of Brian", 'Event Horizon'],
#  ['Clueless', "There's Something About Mary"],
#  ['Kika'],
#  ['Blues Brothers, The', 'Twister'],
#  ['Four Rooms', 'Lady and the Tramp'],
#  ['Naked Gun 33 1/3: The Final Insult'],
#  ['E.T. the Extra-Terrestrial', 'Better Off Dead...', 'Few Good Men, A'],
#  ['Phantasm III: Lord of the Dead',
#   'Mosquito Coast, The',
#   'Rough Magic',
#   'Bad News Bears, The',
#   'Species II',
#   'Dark Crystal, The',
#   'Tales from the Darkside: The Movie',
#   'Criminal Law',
#   'Fargo',
#   'Gattaca',
#   'Seven Year Itch, The',
#   'Thelma & Louise',
#   'Norma Rae',
#   'Die Hard',
#   'Assault on Precinct 13',
#   'Indian in the Cupboard, The',
#   'Repo Man',
#   'Pet Sematary II',
#   'Mr. Mom',
#   'Midnight Cowboy',
#   'Sarafina!',
#   'No Looking Back'],
#  ['Star Wars: Episode IV - A New Hope', 'Romeo and Juliet'],
#  ['Postman, The (Postino, Il)',
#   'Serial Mom',
#   'Ref, The',
#   'Another Stakeout',
#   'Under Siege 2: Dark Territory'],
#  ['Mission: Impossible'],
#  ['Flintstones, The'],
#  ['Talented Mr. Ripley, The'],
#  ['Bourne Identity, The', 'Blues Brothers, The'],
#  ['Meet Dave', 'Fifth Element, The', 'Snake Eyes'],
#  ['Leaving Las Vegas', 'Dances with Wolves'],
#  ['Santa Clause, The', 'Scout, The'],
#  ['American Tail, An'],
#  ['Sixteen Candles'],
#  ['Big',
#   "Breakfast at Tiffany's",
#   'Effect of Gamma Rays on Man-in-the-Moon Marigolds, The'],
#  ['American Beauty'],
#  ['Congo'],
#  ['Radio'],
#  ['Lord of the Rings: The Return of the King, The'],
#  ['Fantasia', 'Dial M for Murder'],
#  ['Some Like It Hot'],
#  ['Net, The'],
#  ["Nobody's Fool",
#   'Snow White and the Seven Dwarfs',
#   'Operation Dumbo Drop',
#   'Home for the Holidays'],
#  ['Hard Candy', 'Taken', 'Lord of War', "Ferris Bueller's Day Off"],
#  ['Green Mile, The',
#   'E.T. the Extra-Terrestrial',
#   'Major League: Back to the Minors'],
#  ['Ghostbusters (a.k.a. Ghost Busters)', 'Office Space'],
#  ['Get Him to the Greek'],
#  ['Wallace & Gromit: The Best of Aardman Animation',
#   '4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile)'],
#  ['Acid House, The'],
#  ['Best in Show', 'Back to the Future'],
#  ['Incredibles, The'],
#  ['My Cousin Vinny',
#   'Triplets of Belleville, The (Les triplettes de Belleville)',
#   'Hedwig and the Angry Inch',
#   'Kung Fu Hustle (Gong fu)',
#   'Lincoln',
#   'Clerks',
#   'Pianist, The',
#   'Vanya on 42nd Street',
#   'Mystic Pizza',
#   'Monster in a Box',
#   'Paths of Glory'],
#  ['Up'],
#  ["Pirates of the Caribbean: Dead Man's Chest"],
#  ['Lord of the Rings: The Two Towers, The'],
#  ['Bourne Ultimatum, The'],
#  ['Watchmen', 'Usual Suspects, The', 'Blue Velvet', 'Up'],
#  ['Life Aquatic with Steve Zissou, The', '300', 'Glengarry Glen Ross'],
#  ['Inception'],
#  ['Heist', 'Terminator 3: Rise of the Machines', 'Miracle'],
#  ['Hitch'],
#  ['Shawshank Redemption, The', 'Net, The'],
#  ['Star Trek: Generations'],
#  ['Saving Private Ryan'],
#  ['Kazaam'],
#  ['Star Trek VI: The Undiscovered Country'],
#  ['Terminator, The', 'Trainspotting'],
#  ['Rear Window',
#   'Family Man, The',
#   'Cocoon',
#   'Silence of the Lambs, The',
#   'Miss Congeniality'],
#  ['Oliver & Company'],
#  ['Princess Bride, The'],
#  ['First Knight'],
#  ['Gattaca', 'Emerald Forest, The'],
#  ['50 First Dates'],
#  ['Jurassic Park',
#   'Lost Souls',
#   'Rocky Horror Picture Show, The',
#   'Misery',
#   'Devil in a Blue Dress',
#   'In & Out',
#   'Piano, The'],
#  ['Juno', 'Curious Case of Benjamin Button, The', 'Matrix Reloaded, The'],
#  ['Striking Distance',
#   'Maverick',
#   'Superstar',
#   'Princess Bride, The',
#   'Funny Farm',
#   'Towering Inferno, The',
#   'Cool Runnings'],
#  ['Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)'],
#  ['Hot Shots! Part Deux'],
#  ['Bowling for Columbine'],
#  ['Indiana Jones and the Last Crusade'],
#  ['Apocalypto',
#   'Charlie and the Chocolate Factory',
#   'Indiana Jones and the Temple of Doom',
#   "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)"],
#  ['Twister'],
#  ['Curious Case of Benjamin Button, The'],
#  ['Batman'],
#  ['Nightmare Before Christmas, The'],
#  ['Jay and Silent Bob Strike Back'],
#  ['K-PAX'],
#  ['Miracle Worker, The'],
#  ['City Hall'],
#  ['Gremlins'],
#  ['Girl with the Dragon Tattoo, The',
#   'K-PAX',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   'Wizard of Oz, The',
#   'Sicko',
#   'House of Sand and Fog'],
#  ['Full Monty, The',
#   'Star Trek: Insurrection',
#   'Dancer in the Dark',
#   'Strange Days'],
#  ['Tangled',
#   'Anastasia',
#   'Sword in the Stone, The',
#   'Warm Bodies',
#   'Roman Holiday'],
#  ['Pat and Mike',
#   'Lady and the Tramp',
#   'Key Largo',
#   'Eternal Sunshine of the Spotless Mind',
#   'Gay Divorcee, The'],
#  ['Amadeus', 'L.A. Confidential', 'Dr. No', 'Johnny Mnemonic'],
#  ['Highlander'],
#  ['Star Trek VI: The Undiscovered Country', 'Miracle on 34th Street'],
#  ['Crimson Tide', 'Mrs. Doubtfire'],
#  ['Ace Ventura: Pet Detective'],
#  ['Terminator, The'],
#  ["Amelie (Fabuleux destin d'Amélie Poulain, Le)", 'Apocalypse Now'],
#  ['Final Fantasy VII: Advent Children',
#   'Edward Scissorhands',
#   'Chinatown',
#   'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The',
#   'Casablanca',
#   'Dawn of the Dead'],
#  ['Wings of Desire (Himmel über Berlin, Der)',
#   'Die Hard',
#   'Craft, The',
#   'Once Upon a Time in America',
#   'Deer Hunter, The',
#   'To Kill a Mockingbird'],
#  ['Pocahontas',
#   'Almost Famous',
#   'Battlefield Earth',
#   "Cat's Eye",
#   'Great Day in Harlem, A',
#   'Prince of Egypt, The',
#   'Red Corner',
#   'Navy Seals',
#   'Sgt. Bilko',
#   'Mystery Men',
#   'From the Journals of Jean Seberg',
#   'As Good as It Gets',
#   'Romeo Must Die'],
#  ['Brazil', 'Star Trek: Insurrection'],
#  ['Romancing the Stone'],
#  ['Silence of the Lambs, The'],
#  ['Not Another Teen Movie', 'Flash Gordon'],
#  ['Twin Peaks: Fire Walk with Me', 'Mystic River', 'NeverEnding Story, The'],
#  ['Angels and Insects'],
#  ['Moonstruck',
#   'Die Hard 2',
#   'Cutting Edge, The',
#   'Karate Kid, Part III, The'],
#  ['Father of the Bride', 'Show Me Love (Fucking Åmål)', 'Teen Wolf'],
#  ['Terminator 2: Judgment Day', 'Eraser'],
#  ['Bad Boys', 'Wedding Singer, The', 'Matrix Revolutions, The'],
#  ['Ring, The', 'Jeepers Creepers', 'Prestige, The'],
#  ['Beavis and Butt-Head Do America'],
#  ['Citizen Kane'],
#  ['To Kill a Mockingbird', "Who's Afraid of Virginia Woolf?"],
#  ['Arrival, The'],
#  ['City of Lost Children, The (Cité des enfants perdus, La)'],
#  ['Seven (a.k.a. Se7en)'],
#  ['Quiz Show', 'Ace Ventura: Pet Detective'],
#  ['Showgirls',
#   'EuroTrip',
#   "National Lampoon's Van Wilder",
#   'Michael Clayton',
#   'Blade II',
#   'Harry Potter and the Chamber of Secrets'],
#  ['Speed 2: Cruise Control'],
#  ['Apostle, The', 'Skin I Live In, The (La piel que habito)'],
#  ['Splash'],
#  ['Clear and Present Danger', 'Igby Goes Down', 'Memento'],
#  ['Running Scared',
#   'Steel Magnolias',
#   'Rebel Without a Cause',
#   'Philadelphia Story, The',
#   'Eight Men Out',
#   'Godfather: Part II, The'],
#  ['Sita Sings the Blues',
#   'Seven Up!',
#   'Why We Fight',
#   'Christmas Tale, A (Un conte de Noël)',
#   'I Served the King of England (Obsluhoval jsem anglického krále)',
#   "Adam's Apples (Adams æbler)",
#   'Sideways',
#   'Revenge of the Pink Panther',
#   "Schindler's List",
#   'Rango'],
#  ['Yellow Submarine',
#   'Sling Blade',
#   "Amelie (Fabuleux destin d'Amélie Poulain, Le)",
#   'Godfather: Part II, The'],
#  ['G.I. Jane'],
#  ['Willy Wonka & the Chocolate Factory', 'Spy Who Loved Me, The'],
#  ['High Tension (Haute tension) (Switchblade Romance)',
#   'Citizen X',
#   'Shogun Assassin',
#   'Exorcist, The',
#   'Rock, The',
#   'Animatrix, The',
#   'Stepford Wives, The',
#   'Crouching Tiger, Hidden Dragon (Wo hu cang long)',
#   'Upside of Anger, The'],
#  ['Seven Days in May'],
#  ['Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'],
#  ['Wizard of Oz, The'],
#  ['Aladdin'],
#  ['Batman Begins', 'Munich', 'Jurassic Park III'],
#  ['Beauty and the Beast', 'Two Weeks Notice'],
#  ['Final Fantasy: The Spirits Within',
#   'Welcome to Woop-Woop',
#   'Elizabethtown',
#   'Holiday, The',
#   'Night of the Iguana, The',
#   'District 9',
#   'X-Files: I Want to Believe, The',
#   'Cloudy with a Chance of Meatballs',
#   'Jackal, The',
#   'Back to the Future',
#   'Inception'],
#  ['Coming to America',
#   '2001: A Space Odyssey',
#   'Crouching Tiger, Hidden Dragon (Wo hu cang long)',
#   'His Girl Friday',
#   'Hoop Dreams',
#   'Usual Suspects, The'],
#  ['Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)',
#   'Brotherhood of the Wolf (Pacte des loups, Le)'],
#  ['Mothman Prophecies, The'],
#  ['Bad Taste'],
#  ['Something the Lord Made', 'Knockaround Guys'],
#  ['K-PAX'],
#  ['Minority Report'],
#  ['Jamaica Inn',
#   'Brief Encounter',
#   'Apartment, The',
#   'Cider House Rules, The',
#   'Angel Eyes',
#   'Road to Utopia',
#   'Lady and the Tramp'],
#  ['American Pie 2', 'High Plains Drifter', "Rosemary's Baby"],
#  ['Star Wars: Episode II - Attack of the Clones',
#   'Spider-Man',
#   'So I Married an Axe Murderer',
#   'Eyes Wide Shut'],
#  ['Broken Arrow', 'Twister', 'Deer Hunter, The', 'Men in Black (a.k.a. MIB)'],
#  ['Mrs. Doubtfire'],
#  ['Graduate, The',
#   'Shakes the Clown',
#   'Full Monty, The',
#   'Longtime Companion',
#   'Snake Eyes',
#   'Oh, God!',
#   'Grave of the Fireflies (Hotaru no haka)',
#   'Idiocracy',
#   'My Cousin Vinny',
#   'Risky Business',
#   'Moscow on the Hudson',
#   'Big Lebowski, The'],
#  ['Pelican Brief, The', 'Star Trek VI: The Undiscovered Country'],
#  ['Little Shop of Horrors', 'Moulin Rouge'],
#  ['Mute Witness'],
#  ['M*A*S*H (a.k.a. MASH)'],
#  ['Clue'],
#  ['Jurassic Park'],
#  ['Great Escape, The',
#   'Five Easy Pieces',
#   'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)'],
#  ['Night of the Living Dead', 'Back to the Future Part II'],
#  ['To Catch a Thief',
#   'Red Shoes, The',
#   'Birdcage, The',
#   'Shine',
#   "What's Eating Gilbert Grape",
#   'Pitch Black',
#   'Blue Angel, The (Blaue Engel, Der)',
#   'Sid and Nancy'],
#  ['Wedding Singer, The', 'American Pie 2'],
#  ['Patton', 'Spitfire Grill, The', 'Grease', 'Volcano'],
#  ['Sneakers'],
#  ['Big Daddy'],
#  ['Best in Show', 'Goodfellas', 'Batman Forever', 'Mummy, The'],
#  ['Aliens',
#   'Dune',
#   "Emperor's New Groove, The",
#   'Quick and the Dead, The',
#   'Back to the Future Part II',
#   'Willow'],
#  ['RoboCop 2',
#   'Payback',
#   'Analyze That',
#   'Thirteenth Floor, The',
#   'Twelve Monkeys (a.k.a. 12 Monkeys)',
#   'Mr. Deeds',
#   'I, Robot',
#   'Princess Bride, The',
#   'Pretty Woman',
#   'Aliens',
#   'Dark Crystal, The',
#   'Boys and Girls',
#   'Citizen Kane',
#   "Look Who's Talking Now"],
#  ['Fantastic Mr. Fox'],
#  ['Scream',
#   'Apollo 13',
#   'Maverick',
#   'Breakfast Club, The',
#   'Gattaca',
#   'Rain Man'],
#  ['Eternal Sunshine of the Spotless Mind'],
#  ['Sense and Sensibility',
#   "One Flew Over the Cuckoo's Nest",
#   'Father of the Bride Part II',
#   'Once Upon a Time in Mexico',
#   'Citizen Kane'],
#  ['Cell 211 (Celda 211)'],
#  ['World Is Not Enough, The'],
#  ['Outbreak', 'True Romance'],
#  ['Mystery Science Theater 3000: The Movie'],
#  ['Addams Family Values'],
#  ['Erin Brockovich', 'What Women Want'],
#  ['Day After Tomorrow, The'],
#  ["It's My Party", 'Mirror Has Two Faces, The'],
#  ['Officer and a Gentleman, An',
#   'Only You',
#   'Simply Irresistible',
#   'Maltese Falcon, The'],
#  ['Nell'],
#  ['Ace Ventura: When Nature Calls'],
#  ['Happy Gilmore', 'Signs', 'Others, The'],
#  ['Scary Movie', '28 Days Later', 'All About My Mother (Todo sobre mi madre)'],
#  ['Grifters, The'],
#  ['Beauty and the Beast',
#   'Barry Lyndon',
#   'Avatar',
#   '21',
#   'Along Came Polly',
#   'Titanic'],
#  ['In a Better World (Hævnen)'],
#  ['American President, The', 'Deep Impact'],
#  ['Charlie and the Chocolate Factory', 'Contact', 'Akira'],
#  ['O Brother, Where Art Thou?',
#   'Devil Wears Prada, The',
#   'E.T. the Extra-Terrestrial',
#   'Buffy the Vampire Slayer'],
#  ['Contact'],
#  ['Pirates of the Caribbean: The Curse of the Black Pearl'],
#  ['Finding Nemo',
#   'My Fair Lady',
#   'Sleepless in Seattle',
#   'Snatch',
#   'Messenger: The Story of Joan of Arc, The',
#   'Bamba, La',
#   'Sound of Music, The',
#   'What Women Want',
#   'Calendar Girls'],
#  ['Sling Blade'],
#  ['Romancing the Stone',
#   "Brain That Wouldn't Die, The",
#   'Time Bandits',
#   'Top Gun'],
#  ['Little Mermaid, The',
#   'Clockwork Orange, A',
#   'Austin Powers: International Man of Mystery',
#   'Roger & Me'],
#  ['Westworld'],
#  ['Shawshank Redemption, The', "Breakfast at Tiffany's"],
#  ['Around the World in 80 Days', 'Iron Giant, The', 'Jewel of the Nile, The'],
#  ['Elementary Particles, The (Elementarteilchen)'],
#  ['Citizen Kane'],
#  ['Submarine',
#   'Accidental Husband, The',
#   'Beauty and the Beast',
#   'Good Will Hunting'],
#  ['Finding Nemo',
#   'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The'],
#  ['Love Bug, The'],
#  ['Blues Brothers, The'],
#  ['Clueless', 'Poltergeist'],
#  ['Dumb & Dumber (Dumb and Dumber)', 'American Tail: Fievel Goes West, An'],
#  ['Baby-Sitters Club, The', 'Die Hard: With a Vengeance'],
#  ['Unbreakable', 'A.I. Artificial Intelligence', 'Mummy Returns, The'],
#  ['Forget Paris',
#   "Breakfast at Tiffany's",
#   'Butch Cassidy and the Sundance Kid'],
#  ['Lethal Weapon 4'],
#  ['Ace Ventura: Pet Detective'],
#  ['Badlands', 'Roger & Me', 'Killer, The (Die xue shuang xiong)'],
#  ['Exorcism of Emily Rose, The', 'Sunshine'],
#  ['Maltese Falcon, The (a.k.a. Dangerous Female)',
#   'Groundhog Day',
#   'Gone with the Wind',
#   'Creature Comforts',
#   'O Brother, Where Art Thou?',
#   'Taxi Driver'],
#  ['X-Men'],
#  ['My Cousin Vinny'],
#  ['Dangerous Minds', 'Don Juan DeMarco'],
#  ["Amelie (Fabuleux destin d'Amélie Poulain, Le)"],
#  ['Close Encounters of the Third Kind'],
#  ['Harriet the Spy'],
#  ['Unforgiven'],
#  ['Ransom', 'Cujo'],
#  ["Can't Hardly Wait",
#   'Fugitive, The',
#   'Mighty Ducks, The',
#   'Dark Knight, The',
#   "Ferris Bueller's Day Off"],
#  ['Crow, The',
#   'Kill Bill: Vol. 1',
#   'Incredible Hulk, The',
#   'American History X',
#   '300'],
#  ['Cinderella Man'],
#  ['Sommersby'],
#  ['Cat Returns, The (Neko no ongaeshi)', 'Juno'],
#  ['Life Aquatic with Steve Zissou, The', 'Lilo & Stitch'],
#  ['Goonies, The', 'Austin Powers: International Man of Mystery', 'Legend'],
#  ['Texas Chainsaw Massacre, The', 'Ring, The'],
#  ['Matrix Revolutions, The', 'Iron Man 2'],
#  ['Balto'],
#  ['Jurassic Park'],
#  ['Sleeper', 'Road Warrior, The (Mad Max 2)', 'Colors', 'Batman'],
#  ['Much Ado About Nothing', 'Sabrina'],
#  ['Kung Fu Hustle (Gong fu)',
#   'Untouchables, The',
#   'South Park: Bigger, Longer and Uncut',
#   'Crouching Tiger, Hidden Dragon (Wo hu cang long)'],
#  ['Homeward Bound II: Lost in San Francisco'],
#  ['American Beauty',
#   'Seven Year Itch, The',
#   'Outsiders, The',
#   'Star Wars: Episode I - The Phantom Menace'],
#  ['Jurassic Park', 'Blast from the Past', 'Lion King, The'],
#  ['Creepshow',
#   'Sleepy Hollow',
#   'Air Force One',
#   'G.I. Jane',
#   'Children of the Corn II: The Final Sacrifice'],
#  ['Deliverance',
#   'Death Wish 2',
#   'Karate Kid, Part III, The',
#   'I Know What You Did Last Summer'],
#  ['Forrest Gump'],
#  ['Harvey'],
#  ['Sting, The', "Muriel's Wedding"],
#  ['Andrei Rublev (Andrey Rublyov)', 'Alien³ (a.k.a. Alien 3)'],
#  ['3 Ninjas Knuckle Up'],
#  ['Forrest Gump', 'Mask, The'],
#  ['2012'],
#  ['Titanic', 'Star Wars: Episode V - The Empire Strikes Back'],
#  ['Yes Man',
#   'Just Cause',
#   'Notebook, The',
#   'Bugsy',
#   'Wizard of Oz, The',
#   'Benchwarmers, The',
#   'Dead Again',
#   'Airport',
#   'What the #$*! Do We Know!? (a.k.a. What the Bleep Do We Know!?)',
#   'Flight of the Phoenix',
#   'Juno',
#   'Exorcist, The',
#   'Back to School',
#   'Gone in 60 Seconds',
#   'Rocky II',
#   'Powder',
#   'Invention of Lying, The',
#   'Chicago'],
#  ['Stray Dog (Nora inu)'],
#  ['Caddyshack', 'Mystery Science Theater 3000: The Movie'],
#  ['Dead Ringers'],
#  ['Casper', "Pirates of the Caribbean: Dead Man's Chest"],
#  ['Austin Powers in Goldmember', "Look Who's Talking Now"],
#  ['Shallow Grave', 'Dead Presidents'],
#  ['Grand Day Out with Wallace and Gromit, A',
#   'Usual Suspects, The',
#   'Chinatown'],
#  ['Watchmen',
#   'Clue',
#   'Airheads',
#   '25th Hour',
#   'Shadow Man',
#   'Mimic 2',
#   'Mission: Impossible',
#   'Old School',
#   'Ghost Dog: The Way of the Samurai',
#   'Tangled',
#   'Cube',
#   'Father of the Bride',
#   'Garden State'],
#  ['Moulin Rouge',
#   'Sin City',
#   'Paper Chase, The',
#   'Hunt for Red October, The',
#   'Absent-Minded Professor, The',
#   'Blair Witch Project, The',
#   'Charade',
#   'Terminator, The',
#   'Pink Floyd: The Wall',
#   '20 Dates',
#   'Great Race, The',
#   'Across the Sea of Time',
#   'Labyrinth',
#   'Fatal Instinct'],
#  ['Robin Hood: Men in Tights', 'Arachnophobia'],
#  ['RoboCop'],
#  ['Gladiator'],
#  ['Clear and Present Danger'],
#  ['Indiana Jones and the Temple of Doom', 'Mulholland Drive'],
#  ['Star Wars: Episode VI - Return of the Jedi'],
#  ['Copycat'],
#  ['Smoke'],
#  ['Hamlet', 'Jack and Sarah', 'Richard III', 'Mighty Aphrodite'],
#  ['Beauty and the Beast',
#   "My Best Friend's Wedding",
#   'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2)'],
#  ['Fifth Element, The'],
#  ["Muriel's Wedding", 'Behind Enemy Lines', '101 Dalmatians'],
#  ['Gone with the Wind',
#   'Escape from New York',
#   '101 Dalmatians',
#   'Meet Me in St. Louis',
#   'Pollyanna'],
#  ['Tommy Boy'],
#  ['Elephant', 'Gloria', 'Virgin Suicides, The'],
#  ['NeverEnding Story III, The',
#   'Cloud Atlas',
#   'Broken Arrow',
#   'Inconvenient Truth, An',
#   'Chinatown',
#   'Independence Day (a.k.a. ID4)',
#   'Matilda',
#   'Down and Out in Beverly Hills',
#   'South Park: Bigger, Longer and Uncut',
#   'Dumb & Dumber (Dumb and Dumber)',
#   'Baxter',
#   'Dan in Real Life',
#   'View to a Kill, A',
#   "Microcosmos (Microcosmos: Le peuple de l'herbe)",
#   'FairyTale: A True Story',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'],
#  ["Once Upon a Time in the West (C'era una volta il West)"],
#  ['Rain Man', 'King of Masks, The (Bian Lian)', 'Erin Brockovich'],
#  ["Men Don't Leave"],
#  ['Blue Velvet'],
#  ['Singles'],
#  ['Forrest Gump', 'Billy Madison'],
#  ['Braveheart'],
#  ['Amarcord', 'Payback', 'Few Good Men, A'],
#  ['Honey, I Shrunk the Kids',
#   'Hoosiers (a.k.a. Best Shot)',
#   'Short Cuts',
#   'Notting Hill',
#   'Reality Bites',
#   'Victory (a.k.a. Escape to Victory)',
#   'Insomnia',
#   'Some Kind of Wonderful',
#   "Amores Perros (Love's a Bitch)",
#   'Flightplan',
#   'Good Will Hunting',
#   'It Could Happen to You',
#   'Masquerade',
#   'Edward Scissorhands',
#   '8 1/2 (8½)'],
#  ['Stargate',
#   'Indiana Jones and the Last Crusade',
#   'Men in Black (a.k.a. MIB)',
#   'Batman Returns'],
#  ['Byzantium',
#   "Amelie (Fabuleux destin d'Amélie Poulain, Le)",
#   'Scent of a Woman',
#   'Batman & Robin',
#   'Million Dollar Baby',
#   'Matador, The',
#   'What Women Want',
#   'Final Destination, The (Final Destination 4) (Final Destination in 3-D, The)',
#   'Scream 4'],
#  ['E.T. the Extra-Terrestrial'],
#  ['Star Trek IV: The Voyage Home',
#   'Godzilla 1985: The Legend Is Reborn (Gojira) (Godzilla) (Return of Godzilla, The)',
#   'Dogma'],
#  ["Amelie (Fabuleux destin d'Amélie Poulain, Le)"],
#  ['Graduate, The', 'Ghost'],
#  ['Wall Street',
#   'Mighty Wind, A',
#   'Groundhog Day',
#   'Enter the Dragon',
#   'Mad Max Beyond Thunderdome',
#   'Monty Python Live at the Hollywood Bowl'],
#  ['American Beauty'],
#  ['Kids in the Hall: Brain Candy', 'Rosencrantz and Guildenstern Are Dead'],
#  ['L.A. Confidential'],
#  ['Star Trek II: The Wrath of Khan',
#   'Star Wars: Episode IV - A New Hope',
#   'Courage Under Fire'],
#  ['M*A*S*H (a.k.a. MASH)',
#   'Aliens',
#   'A.I. Artificial Intelligence',
#   'Day the Earth Stood Still, The',
#   'Phantom of the Paradise',
#   'Farewell My Concubine (Ba wang bie ji)',
#   'Pixote'],
#  ['Real Genius',
#   'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)',
#   'Radio Flyer',
#   'Contact'],
#  ['North by Northwest', 'Total Recall'],
#  ['Wizard of Oz, The'],
#  ['Happiness'],
#  ["Murphy's Romance"],
#  ['War of the Worlds', 'Blow-Out (La grande bouffe)', 'Black Swan'],
#  ['Apollo 13', "Razor's Edge, The"],
#  ['Lion King, The'],
#  ['Apollo 13',
#   'Rushmore',
#   'Paradise Lost: The Child Murders at Robin Hood Hills'],
#  ['Braveheart', 'Cinderella'],
#  ["One Flew Over the Cuckoo's Nest"],
#  ['Super Mario Bros.',
#   'Mission: Impossible',
#   'Little Rascals, The',
#   'Showgirls'],
#  ['Goldfinger'],
#  ['Lives of Others, The (Das leben der Anderen)',
#   'Batman Forever',
#   'American Pie 2',
#   'Dumb & Dumber (Dumb and Dumber)',
#   'Final Destination'],
#  ['Braveheart', '1984 (Nineteen Eighty-Four)'],
#  ['Elf'],
#  ["Boys Don't Cry"],
#  ['African Queen, The'],
#  ['Full Metal Jacket', 'Escape from Alcatraz'],
#  ['Lion King, The'],
#  ['Crow, The', 'Stargate'],
#  ['Robin Hood: Men in Tights'],
#  ['Tank',
#   'Wrongfully Accused',
#   'Blacula',
#   'Saving Private Ryan',
#   'Ragtime',
#   'Life Less Ordinary, A'],
#  ['Seven (a.k.a. Se7en)'],
#  ['Net, The', 'Billy Madison'],
#  ['Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)',
#   'Who Framed Roger Rabbit?'],
#  ['Celluloid Closet, The'],
#  ['Re-Animator'],
#  ['Mad Max Beyond Thunderdome',
#   'Manchurian Candidate, The',
#   'Planet Terror',
#   'Atomic Cafe, The',
#   'Mina Tannenbaum',
#   'Full Metal Jacket',
#   'American Hustle',
#   'Hunger Games, The',
#   'Amazon Women on the Moon'],
#  ['Ben-Hur', 'Spy Who Loved Me, The'],
#  ['Sherlock Holmes: A Game of Shadows'],
#  ['Nell', 'Spider-Man', 'Shanghai Surprise'],
#  ['Gladiator'],
#  ['Maverick', 'Airheads', 'Wyatt Earp'],
#  ['1941', 'In Cold Blood'],
#  ['True Lies'],
#  ['Muppets Take Manhattan, The',
#   'This Is Spinal Tap',
#   'Godfather: Part II, The'],
#  ['Day After Tomorrow, The', 'Titan A.E.', 'Tuxedo, The'],
#  ['Fish Called Wanda, A'],
#  ['Interview with the Vampire: The Vampire Chronicles'],
#  ['Postman, The (Postino, Il)', 'Changeling', 'Four Weddings and a Funeral'],
#  ['Armageddon', 'Paulie', 'Live and Let Die', 'Simple Wish, A'],
#  ['Blade Runner',
#   'Philadelphia',
#   'Back to the Future',
#   'Desperado',
#   'Being John Malkovich'],
#  ['RocknRolla', 'Stuck', 'Gladiator', 'Escapist, The', 'Sunshine Cleaning'],
#  ['Clueless'],
#  ['Pink Panther Strikes Again, The',
#   'Live and Let Die',
#   'Fear and Loathing in Las Vegas',
#   'Texas Chainsaw Massacre: The Next Generation (a.k.a. The Return of the Texas Chainsaw Massacre)',
#   'Cocoon',
#   "My Best Friend's Wedding",
#   'Mermaids',
#   'Hanky Panky',
#   'Erin Brockovich',
#   'Galaxy Quest',
#   'Ghost Rider',
#   'Underground',
#   'Mitchell',
#   "Breakin' 2: Electric Boogaloo",
#   'Freddy vs. Jason',
#   'Fort Apache',
#   'Alien',
#   'Spartacus',
#   'Little Man Tate',
#   'Piano Teacher, The (La pianiste)',
#   "Child's Play",
#   'Adaptation',
#   'Bad Lieutenant',
#   'Last Tango in Paris (Ultimo tango a Parigi)',
#   'Two Jakes, The',
#   'Sleepers',
#   'Elvira, Mistress of the Dark',
#   'Basket Case 2',
#   'Victory (a.k.a. Escape to Victory)',
#   'I Know Who Killed Me',
#   'Sorority House Massacre',
#   'Manhunter'],
#  ['Being John Malkovich'],
#  ['Wizard of Oz, The',
#   'Hoosiers (a.k.a. Best Shot)',
#   'E.T. the Extra-Terrestrial',
#   'Hollow Man'],
#  ['Spy Game'],
#  ['Trainspotting', 'Matrix, The'],
#  ['Naked Gun 33 1/3: The Final Insult'],
#  ['Nightmare Before Christmas, The', 'Diabolique'],
#  ['Blue Streak', 'Young Frankenstein'],
#  ["Muriel's Wedding"],
#  ['Ready to Wear (Pret-A-Porter)'],
#  ['Delicatessen'],
#  ['Star Wars: Episode IV - A New Hope'],
#  ['Man Without a Face, The', 'Dances with Wolves'],
#  ['Taxi Driver', 'True Romance', 'Private Parts', 'Sirens'],
#  ['Apostle, The'],
#  ['Little Women'],
#  ['Clueless',
#   'Skin, Skin (Käpy selän alla)',
#   'Tetsuo, the Ironman (Tetsuo)',
#   'Executive Decision',
#   'Basic',
#   'Battle Royale 2: Requiem (Batoru rowaiaru II: Chinkonka)',
#   'Snake Eyes',
#   'Bad Boys',
#   'Cotton Club, The',
#   'Sucker Punch',
#   'Road Trip',
#   'Hills Have Eyes II, The',
#   'Raising Arizona',
#   'Saw',
#   'King Kong',
#   'Wash, The',
#   'Iron Man',
#   'Meet Joe Black',
#   'Derailed',
#   'Babylon 5: Thirdspace',
#   'Score, The',
#   '28 Days Later'],
#  ['Three Colors: White (Trzy kolory: Bialy)',
#   'Village of the Damned',
#   'Three Musketeers, The'],
#  ['Madness of King George, The'],
#  ['Memento', 'Quiet Man, The'],
#  ['Billy Jack',
#   'Brigham City',
#   'Adventures of Priscilla, Queen of the Desert, The',
#   'True Grit',
#   'Adventures of Ichabod and Mr. Toad, The',
#   'Drunken Master (Jui kuen)',
#   'In the Line of Fire',
#   'Weird Science',
#   'Affair to Remember, An',
#   'Star Wars: Episode IV - A New Hope',
#   'Edward Scissorhands',
#   'Terminator, The',
#   'Tombstone',
#   'Lean on Me',
#   'Romper Stomper',
#   'Arthur',
#   'Abyss, The',
#   'Halloween 5: The Revenge of Michael Myers',
#   'Serial Mom',
#   'Judgment at Nuremberg'],
#  ['Lizzie McGuire Movie, The',
#   'Roustabout',
#   'Six Degrees of Separation',
#   'Crocodile Hunter: Collision Course, The'],
#  ['28 Days',
#   'House of Flying Daggers (Shi mian mai fu)',
#   'Bad Santa',
#   'Into the Blue',
#   'Client, The',
#   'Jagged Edge',
#   'Kids in the Hall: Brain Candy',
#   'Die Hard',
#   'Girl, Interrupted'],
#  ['101 Dalmatians (One Hundred and One Dalmatians)',
#   'Aristocats, The',
#   'If....',
#   'Birdcage, The'],
#  ['Unbreakable'],
#  ['Beetlejuice'],
#  ['Stargate'],
#  ['Limitless', "Porky's", '50 First Dates'],
#  ['Re-Animator', 'Hook', 'Wolf Man, The'],
#  ['Barbershop', 'Insomnia', 'My Big Fat Greek Wedding', 'Top Gun'],
#  ['Strangers on a Train', "Antonia's Line (Antonia)"],
#  ['Misérables, Les'],
#  ['Tom and Huck', 'Radio Days', 'F/X', 'Glory', 'Few Good Men, A'],
#  ['Nightmare on Elm Street, A'],
#  ['Tommy Boy'],
#  ['Four Weddings and a Funeral'],
#  ['On the Waterfront'],
#  ['Searching for Bobby Fischer',
#   'X-Files: Fight the Future, The',
#   'Once Upon a Time in Mexico',
#   'When Harry Met Sally...',
#   'Lion King, The',
#   'Pi',
#   'Perfect Murder, A'],
#  ['From Dusk Till Dawn', 'Mission: Impossible'],
#  ['League of Extraordinary Gentlemen, The (a.k.a. LXG)'],
#  ['My Big Fat Greek Wedding'],
#  ['Evil Dead II (Dead by Dawn)'],
#  ['Lion King, The', 'Hamlet', 'Harry Potter and the Goblet of Fire'],
#  ['Something Wicked This Way Comes', "There's Something About Mary"],
#  ['Nosferatu (Nosferatu, eine Symphonie des Grauens)',
#   'American Pie',
#   'Four Rooms'],
#  ['X-Files: Fight the Future, The'],
#  ['Independence Day (a.k.a. ID4)',
#   'Jurassic Park',
#   'Star Wars: Episode IV - A New Hope',
#   'Letters to Juliet',
#   'Star Wars: Episode I - The Phantom Menace',
#   'Monuments Men, The'],
#  ["Schindler's List"],
#  ["Bridget Jones's Diary"],
#  ['Batman & Robin'],
#  ['Billy Madison', 'Nell', 'Executive Decision', 'Rudy'],
#  ['Silence of the Lambs, The'],
#  ['Frozen',
#   'Act of Killing, The',
#   'Hangover, The',
#   'Bad Lieutenant: Port of Call New Orleans',
#   'Happiness',
#   'Fast & Furious 6 (Fast and the Furious 6, The)'],
#  ['Simpsons Movie, The', 'xXx: State of the Union'],
#  ['Psycho', 'Poltergeist'],
#  ['Daredevil'],
#  ['Wings of Desire (Himmel über Berlin, Der)',
#   'Evil Dead, The',
#   'Beverly Hills Cop II',
#   'Down by Law',
#   '10',
#   'Much Ado About Nothing',
#   'Crash',
#   'Cocktail',
#   'Troy'],
#  ['Lord of the Rings: The Return of the King, The'],
#  ['Three Musketeers, The'],
#  ['Saving Private Ryan'],
#  ['Cloudy with a Chance of Meatballs'],
#  ['Pumpkin', "King Solomon's Mines", 'Good Earth, The'],
#  ['Batman Forever'],
#  ['Room with a View, A'],
#  ['Crow, The', 'Mystic Pizza'],
#  ['World Is Not Enough, The', 'Sarafina!'],
#  ['Flashpoint'],
#  ['G.I. Joe: Retaliation',
#   'Fantastic Four: Rise of the Silver Surfer',
#   'Resident Evil: Extinction'],
#  ['Chinatown'],
#  ['Stand by Me', 'Forrest Gump', 'Notting Hill', 'Back to the Future'],
#  ['Star Wars: Episode I - The Phantom Menace'],
#  ['Congo'],
#  ['Naked Gun 33 1/3: The Final Insult',
#   'Fried Green Tomatoes',
#   'Pursuit of Happyness, The'],
#  ['Beauty and the Beast'],
#  ['Young Frankenstein'],
#  ['While You Were Sleeping'],
#  ['Shrek'],
#  ['Lethal Weapon'],
#  ['Dragonheart', 'Dead Poets Society'],
#  ["One Flew Over the Cuckoo's Nest"],
#  ['War, The', 'Braveheart'],
#  ['Lord of the Rings: The Fellowship of the Ring, The',
#   'Jay and Silent Bob Strike Back',
#   'Dazed and Confused'],
#  ['Saw III'],
#  ["It's the Great Pumpkin, Charlie Brown"],
#  ["Pan's Labyrinth (Laberinto del fauno, El)"],
#  ['Princess Bride, The',
#   'Shall We Dance',
#   'Three Colors: Blue (Trois couleurs: Bleu)',
#   'Iron Eagle',
#   'Rain Man',
#   'Toy Story',
#   'Donnie Brasco',
#   'Lady and the Tramp',
#   'American History X'],
#  ['Double Indemnity', 'Pride and Prejudice'],
#  ['Léon: The Professional (a.k.a. The Professional) (Léon)'],
#  ['Alien: Resurrection',
#   'Mystery Science Theater 3000: The Movie',
#   'October Sky',
#   'Scream'],
#  ['Aristocats, The'],
#  ['Lord of the Rings: The Two Towers, The'],
#  ['Kick-Ass', 'Jurassic Park', 'Speed', 'Star Trek V: The Final Frontier'],
#  ['Where the Money Is',
#   'Roger & Me',
#   'Critters 2: The Main Course',
#   "Losin' It",
#   "Man Bites Dog (C'est arrivé près de chez vous)",
#   'Independence Day (a.k.a. ID4)',
#   'Lara Croft: Tomb Raider',
#   'Mickey Blue Eyes',
#   'Family Thing, A',
#   'Shampoo',
#   'Entrapment',
#   'Player, The',
#   'Mrs. Parker and the Vicious Circle',
#   'Falcon and the Snowman, The',
#   'Cocoon',
#   'Contact',
#   'Dirty Work',
#   'Bronx Tale, A',
#   'Waiting to Exhale',
#   'Right Stuff, The',
#   'Firewalker',
#   'Colors',
#   'Sunset Blvd. (a.k.a. Sunset Boulevard)',
#   'Best in Show',
#   "Peter's Friends",
#   'Manhattan Murder Mystery',
#   'Empire Records',
#   'Out of Africa',
#   'River Runs Through It, A',
#   'Get Shorty',
#   'Spawn',
#   'Baraka',
#   'Twilight',
#   'Stupids, The',
#   'Mr. Wonderful',
#   'Liberty Heights',
#   'Best of the Best',
#   'Palmetto',
#   "Pete's Dragon",
#   'Copycat',
#   'Dark Half, The'],
#  ['Stargate', 'Cocoon'],
#  ['Silence of the Lambs, The', 'Caddyshack'],
#  ['Outbreak', 'Demolition Man'],
#  ['Killer, The (Die xue shuang xiong)'],
#  ['Dan in Real Life',
#   'Blues Brothers, The',
#   'Longest Day, The',
#   'Pinocchio',
#   'Father of the Bride Part II',
#   'Fracture',
#   'Midnight in Paris',
#   'Midnight Run',
#   'District 9'],
#  ['Saving Grace'],
#  ['Willy Wonka & the Chocolate Factory',
#   'Cliffhanger',
#   'Dumb & Dumber (Dumb and Dumber)',
#   'Fistful of Dollars, A (Per un pugno di dollari)'],
#  ['Ed Wood', 'Firm, The'],
#  ['Billy Elliot', 'Silence of the Lambs, The'],
#  ['Starship Troopers'],
#  ['Ace Ventura: Pet Detective', 'Ghostbusters (a.k.a. Ghost Busters)'],
#  ['Toy Story', 'Silence of the Lambs, The'],
#  ['Working Girl', 'Frida', 'Rocketeer, The'],
#  ['Terminator 2: Judgment Day'],
#  ['Lion King, The'],
#  ['Demolition Man'],
#  ['Karate Kid, Part II, The',
#   'Ghostbusters (a.k.a. Ghost Busters)',
#   'Fifth Element, The'],
#  ['Johnny Mnemonic', 'Truman Show, The'],
#  ['Usual Suspects, The'],
#  ['Dancer in the Dark', 'Mighty Wind, A'],
#  ['House of Games',
#   'Clear and Present Danger',
#   'Poltergeist',
#   'Long Good Friday, The'],
#  ['Stargate'],
#  ['Paths of Glory'],
#  ['Sherlock Holmes: A Game of Shadows'],
#  ['Dances with Wolves'],
#  ['Braveheart'],
#  ['Waterboy, The',
#   'Backdraft',
#   'Gung Ho',
#   'Game, The',
#   'Love Affair',
#   'Piranha',
#   'Dangerous Liaisons'],
#  ['Clueless', 'Fugitive, The'],
#  ['Courage Under Fire'],
#  ['Casino Royale'],
#  ['Lord of the Rings: The Fellowship of the Ring, The'],
#  ['Shawshank Redemption, The'],
#  ['Lost Boys, The',
#   'Town, The',
#   'Elysium',
#   'Adventures of Tintin, The',
#   'Die Hard',
#   'Hostel: Part III'],
#  ['Soul Man',
#   'Deliverance',
#   'Jerk, The',
#   'GoldenEye',
#   'Event Horizon',
#   'Batman Forever',
#   'Flight of the Navigator'],
#  ['Queen, The',
#   'Halloween',
#   'Tommy Boy',
#   'Reservoir Dogs',
#   'Hedwig and the Angry Inch',
#   'Ace Ventura: Pet Detective',
#   'Robin Hood',
#   'Born in East L.A.',
#   'Anchorman: The Legend of Ron Burgundy',
#   'American Psycho',
#   'Few Good Men, A',
#   'Jason and the Argonauts'],
#  ['Multiplicity'],
#  ['Eddie Murphy Raw'],
#  ["Something's Gotta Give"],
#  ['Interview with the Vampire: The Vampire Chronicles', 'Pulp Fiction'],
#  ['Bicentennial Man', 'Office Space', 'Forget Paris'],
#  ['For the Birds'],
#  ['Indian in the Cupboard, The',
#   'Sleepless in Seattle',
#   'Richie Rich',
#   'Léon: The Professional (a.k.a. The Professional) (Léon)'],
#  ['Enemy of the State'],
#  ['Dead Ringers',
#   '3000 Miles to Graceland',
#   'Storytelling',
#   'Under Siege',
#   'Rules of Attraction, The',
#   'Me Myself I',
#   'Crocodile Dundee II',
#   'Ringu (Ring)',
#   'Jungle Book, The',
#   'Resident Evil',
#   'Dog Soldiers',
#   'Blade Runner',
#   'Cape Fear',
#   'Dangerous Minds',
#   'Howling IV: The Original Nightmare',
#   'Do the Right Thing',
#   "Dude, Where's My Car?",
#   'Mr. Nice Guy (Yat goh ho yan)',
#   'Navy Seals',
#   'Leaving Las Vegas',
#   'Ishtar',
#   "Bride of Chucky (Child's Play 4)",
#   '84 Charing Cross Road',
#   'Friday the 13th Part IV: The Final Chapter',
#   'Incredibles, The',
#   'Mariachi, El'],
#  ['Dead Man Walking'],
#  ['Toy Story 2', 'Jurassic Park'],
#  ['Haunting, The'],
#  ['Monty Python and the Holy Grail',
#   'Star Wars: Episode VI - Return of the Jedi'],
#  ['Ace Ventura: When Nature Calls', "Don't Say a Word"],
#  ['Vicky Cristina Barcelona'],
#  ['Casino Royale', 'Diamonds Are Forever', 'Rocky Horror Picture Show, The'],
#  ['Traffic'],
#  ['Fox and the Hound, The', 'Lost in Translation'],
#  ['Princess Bride, The'],
#  ['Independence Day (a.k.a. ID4)'],
#  ['Princess Bride, The'],
#  ['Back to the Future', 'Lost Highway', 'Liar Liar', 'Beauty and the Beast'],
#  ['Executive Decision'],
#  ['NeverEnding Story II: The Next Chapter, The'],
#  ['Ideal Husband, An',
#   'Tomorrow Never Dies',
#   'Romancing the Stone',
#   'Dick',
#   'Executive Decision',
#   'Footloose',
#   'Agnes of God',
#   'Earth Girls Are Easy'],
#  ['To Wong Foo, Thanks for Everything! Julie Newmar'],
#  ["Ocean's Twelve", 'Gladiator'],
#  ['Big Sleep, The'],
#  ['Apollo 13', 'Quiz Show'],
#  ['Monsters, Inc.', 'Much Ado About Nothing'],
#  ['Robin Hood: Prince of Thieves'],
#  ['Ice Age'],
#  ['Star Trek: Generations'],
#  ['In America'],
#  ['25th Hour',
#   "Ferris Bueller's Day Off",
#   'Seven (a.k.a. Se7en)',
#   "March of the Penguins (Marche de l'empereur, La)",
#   'American Pie 2',
#   'Talented Mr. Ripley, The'],
#  ['Tommy Boy'],
#  ['League of Their Own, A',
#   'In Too Deep',
#   'Hud',
#   'Stiff Upper Lips',
#   'Army of Darkness'],
#  ['Sleepers'],
#  ['Brady Bunch Movie, The'],
#  ['Crazy/Beautiful', '10 Things I Hate About You'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ["Child's Play 2"],
#  ['Ace Ventura: When Nature Calls'],
#  ['Glory'],
#  ["Boys Don't Cry", 'Ghost'],
#  ["Widows' Peak", "Antonia's Line (Antonia)", 'Maverick'],
#  ['Thousand Acres, A'],
#  ['King Kong',
#   'Band of Brothers',
#   'Go',
#   'Stranger than Fiction',
#   'Rock, The',
#   'X-Men: The Last Stand'],
#  ['Yi Yi', 'Backdraft', 'Naked Lunch', 'Patton'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ['Demolition Man'],
#  ['Frequency'],
#  ['Where the Money Is', 'See No Evil, Hear No Evil', 'Fisher King, The'],
#  ['Quiz Show', 'Miracle on 34th Street'],
#  ['Ace Ventura: Pet Detective', 'Crimson Tide'],
#  ['Sixth Sense, The'],
#  ['Star Trek III: The Search for Spock'],
#  ['L.A. Confidential'],
#  ['Dragonheart'],
#  ['Thirteen Days'],
#  ['Daylight',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Rush Hour',
#   'Liar Liar',
#   'Dangerous Minds'],
#  ['American Pie'],
#  ['Boondock Saints, The',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Wallace & Gromit: The Best of Aardman Animation',
#   'Indiana Jones and the Temple of Doom',
#   'Wallace & Gromit: The Wrong Trousers'],
#  ['Duck Soup'],
#  ['Harvey'],
#  ['Speed 2: Cruise Control',
#   'Austin Powers: The Spy Who Shagged Me',
#   'River Wild, The',
#   'Total Recall',
#   'G.I. Jane'],
#  ['Thing, The'],
#  ['Nightmare Before Christmas, The'],
#  ['Hook', 'Mask, The', 'Predator 2'],
#  ['Taxi Driver', 'Lion King, The'],
#  ['City of Angels'],
#  ['Star Wars: Episode VI - Return of the Jedi'],
#  ['Miss Firecracker',
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Wag the Dog',
#   'Shining, The',
#   'Mrs. Doubtfire',
#   'Being John Malkovich'],
#  ["Charlie's Angels: Full Throttle"],
#  ['Three Kings',
#   'Cruel Intentions',
#   'Titanic',
#   'Austin Powers: International Man of Mystery',
#   'Ghost',
#   'People vs. Larry Flynt, The',
#   'Babe'],
#  ['Up Close and Personal', 'Eddie'],
#  ['Santa Clause, The'],
#  ['Godfather: Part II, The', 'Maltese Falcon, The'],
#  ['Watchmen'],
#  ['Frankenstein',
#   'Escape from L.A.',
#   'Terminator 2: Judgment Day',
#   'World of Apu, The (Apur Sansar)',
#   'Untouchables, The'],
#  ['Secretariat', 'City of Lost Children, The (Cité des enfants perdus, La)'],
#  ['Matrix, The', 'Chocolat'],
#  ['Shipping News, The',
#   'What Ever Happened to Baby Jane?',
#   'Mr. Saturday Night',
#   'Welcome to Collinwood',
#   'Warlock',
#   'Proof',
#   'Drumline'],
#  ['Virtuosity'],
#  ['Philadelphia', 'Down Periscope'],
#  ['Bicycle Thieves (a.k.a. The Bicycle Thief) (a.k.a. The Bicycle Thieves) (Ladri di biciclette)',
#   'French Connection, The'],
#  ['Coneheads', 'Hamlet', 'Untouchables, The'],
#  ['Rear Window', 'Hot Chick, The', "Can't Hardly Wait"],
#  ['World According to Garp, The'],
#  ['Back to the Future Part II'],
#  ['Aliens', 'Johnny Mnemonic'],
#  ['Dances with Wolves',
#   'Dirty Dancing',
#   'Weird Science',
#   'Grand Day Out with Wallace and Gromit, A',
#   'Sixth Sense, The',
#   'Lightning Jack',
#   "Schindler's List",
#   "Devil's Own, The"],
#  ['Toy Story', "One Flew Over the Cuckoo's Nest"],
#  ['Brassed Off',
#   'Flirt',
#   'Interiors',
#   'Harder They Come, The',
#   'My Man Godfrey'],
#  ['Italian Job, The', 'Into the Wild', 'Happy Feet Two'],
#  ['Underworld'],
#  ['Strangers on a Train'],
#  ['Return of the Living Dead, The'],
#  ['Babe', 'Cliffhanger'],
#  ['Breaker Morant', 'Strange Days'],
#  ['Shining, The', 'Goldfinger'],
#  ['Unforgiven',
#   'Fatal Attraction',
#   'For a Few Dollars More (Per qualche dollaro in più)',
#   'Allan Quatermain and the Lost City of Gold',
#   'Semi-Tough',
#   'Bronx Tale, A',
#   'Monty Python and the Holy Grail',
#   'Jules and Jim (Jules et Jim)',
#   'Car Wash'],
#  ['Some Kind of Wonderful',
#   'Last of the Mohicans, The',
#   "Dracula (Bram Stoker's Dracula)"],
#  ['Rock, The'],
#  ["Romy and Michele's High School Reunion", 'American Pie 2'],
#  ["Nobody's Fool"],
#  ['Jackass: The Movie'],
#  ["Bug's Life, A", 'Zoolander', 'Whole Nine Yards, The', 'Abyss, The'],
#  ['Game, The'],
#  ['Searchers, The',
#   'American History X',
#   'I Know What You Did Last Summer',
#   'South Park: Bigger, Longer and Uncut',
#   'Wild Strawberries (Smultronstället)',
#   'Running Scared'],
#  ['My Big Fat Greek Wedding',
#   'Eyes Wide Shut',
#   'Toy Story 2',
#   'Ratatouille',
#   'Lethal Weapon 2',
#   'Stuart Little 2'],
#  ['Memento'],
#  ['Bone Collector, The', "Bug's Life, A"],
#  ['Star Wars: Episode V - The Empire Strikes Back'],
#  ["Ferris Bueller's Day Off"],
#  ['Star Wars: Episode V - The Empire Strikes Back',
#   'Benny & Joon',
#   'Better Off Dead...'],
#  ['Throw Momma from the Train',
#   'Grease',
#   'Back to the Future',
#   'Notting Hill',
#   'Save the Last Dance'],
#  ['Cocoon', 'Moonraker'],
#  ['Dances with Wolves'],
#  ['Braveheart'],
#  ['Goldfinger', 'My Cousin Vinny', 'Life', 'Dumbo', 'Jaws', '50 First Dates'],
#  ['Buddy Holly Story, The', 'Player, The'],
#  ['Grand Day Out with Wallace and Gromit, A',
#   'Man in the Iron Mask, The',
#   'Sister Act',
#   'Distinguished Gentleman, The'],
#  ['Mask of Zorro, The',
#   'American in Paris, An',
#   "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone)"],
#  ['Seven (a.k.a. Se7en)'],
#  ['Jaws',
#   'Cannonball Run, The',
#   "City Slickers II: The Legend of Curly's Gold"],
#  ['Godfather, The',
#   'Shawshank Redemption, The',
#   'Enemy Mine',
#   'Pleasantville'],
#  ['Siege, The',
#   'Firm, The',
#   'Shrek',
#   'Pi',
#   'Hollow Man',
#   'Ghost',
#   'Mexican, The',
#   'Alfie',
#   'Déjà Vu (Deja Vu)',
#   'Man Who Fell to Earth, The',
#   'Grindhouse',
#   'Galaxy Quest'],
#  ['40-Year-Old Virgin, The'],
#  ['View to a Kill, A',
#   'Mummy, The',
#   'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2)',
#   'Batman & Robin',
#   'Anaconda',
#   'Abyss, The'],
#  ['Die Hard'],
#  ['Independence Day (a.k.a. ID4)', 'Carnosaur 3: Primal Species'],
#  ['Stranger than Fiction'],
#  ['Kiss the Girls', 'Taxi Driver', 'Cell, The'],
#  ['Silence of the Lambs, The'],
#  ['Biutiful',
#   'Mighty Aphrodite',
#   'Craft, The',
#   'Few Good Men, A',
#   'Where the Wild Things Are',
#   'Planet of the Apes',
#   'Fried Green Tomatoes'],
#  ['Twister', 'Mission: Impossible', 'Speed'],
#  ['O Brother, Where Art Thou?'],
#  ['Silence of the Lambs, The'],
#  ['Payback', 'Star Wars: Episode V - The Empire Strikes Back', 'Con Air'],
#  ["One Flew Over the Cuckoo's Nest"],
#  ['52 Pick-Up'],
#  ['Waterworld', 'Tropic Thunder'],
#  ['Kiss of the Dragon'],
#  ['Happy Gilmore',
#   'NeverEnding Story II: The Next Chapter, The',
#   'Face/Off',
#   'Forrest Gump'],
#  ['Up Close and Personal', 'Escape from L.A.'],
#  ['Return of the Living Dead Part II',
#   'Amazing Spider-Man, The',
#   'Top Gun',
#   'Eight Legged Freaks',
#   'Commando',
#   'Sixteen Candles',
#   'Van Helsing',
#   "Knight's Tale, A"],
#  ['Grand Day Out with Wallace and Gromit, A'],
#  ['Shaun of the Dead'],
#  ['Sabrina'],
#  ['Clockwork Orange, A'],
#  ['Thousand Acres, A', 'Clear and Present Danger'],
#  ['Fatal Attraction'],
#  ['McLintock!', 'D2: The Mighty Ducks'],
#  ["There's Something About Mary"],
#  ['Land and Freedom (Tierra y libertad)'],
#  ['Inception'],
#  ['Year of Living Dangerously, The', 'Game, The'],
#  ['Tombstone'],
#  ['Seven (a.k.a. Se7en)'],
#  ['Hook', 'Gladiator', 'Harry Potter and the Prisoner of Azkaban'],
#  ['Mission to Mars', 'Lost World: Jurassic Park, The', 'Loser', 'Apollo 13'],
#  ["Amores Perros (Love's a Bitch)",
#   'Fifth Element, The',
#   'Matrix Reloaded, The'],
#  ['All About My Mother (Todo sobre mi madre)'],
#  ['Dirty Dancing',
#   'George of the Jungle',
#   "One Flew Over the Cuckoo's Nest",
#   'Back to the Future Part II',
#   '¡Three Amigos!',
#   'Rocky II'],
#  ['American History X'],
#  ['Pianist, The',
#   'American Psycho II: All American Girl',
#   "Pan's Labyrinth (Laberinto del fauno, El)",
#   'Kill Bill: Vol. 2',
#   'Libeled Lady',
#   'Lawrence of Arabia'],
#  ['X-Men'],
#  ['Mad Max'],
#  ['Robin Hood: Men in Tights'],
#  ['River Wild, The',
#   'Age of Innocence, The',
#   'Secret Garden, The',
#   "Schindler's List",
#   'Three Musketeers, The'],
#  ['No Country for Old Men',
#   'Star Trek VI: The Undiscovered Country',
#   'Death Machine',
#   'Interview with the Vampire: The Vampire Chronicles',
#   'Trapped'],
#  ['Substitute, The'],
#  ['Pet Sematary',
#   'Blade Runner',
#   'Batman',
#   'Joe Somebody',
#   "There's Something About Mary",
#   'Scrooged',
#   'Deep Blue Sea'],
#  ['Bone Collector, The'],
#  ['Seven (a.k.a. Se7en)'],
#  ['Starsky & Hutch', 'Secret Window', 'Specialist, The', 'Babel', 'Torque'],
#  ['Jurassic Park'],
#  ['Edward Scissorhands',
#   'Superman II',
#   'Independence Day (a.k.a. ID4)',
#   'Adventures of Buckaroo Banzai Across the 8th Dimension, The',
#   'Inspector Gadget',
#   'Black Cauldron, The',
#   'Con Air'],
#  ['American Pie', 'Demolition Man'],
#  ['Gods and Monsters'],
#  ['Day the Earth Stood Still, The'],
#  ['My Neighbor Totoro (Tonari no Totoro)', 'Secret Garden, The'],
#  ['Made in America', 'Just Cause', 'Sling Blade', 'Clueless'],
#  ['Age of Innocence, The',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Young Frankenstein',
#   'Breaking the Waves'],
#  ['Last Man Standing'],
#  ['Gremlins', 'Back to the Future Part III'],
#  ["Kiki's Delivery Service (Majo no takkyûbin)",
#   'Ratatouille',
#   '39 Steps, The',
#   'Hangover, The',
#   'WALL·E'],
#  ['Mrs. Doubtfire', 'Dolores Claiborne', 'Wizard of Oz, The'],
#  ['Omen, The', 'Braveheart'],
#  ['Lion King, The', 'Star Wars: Episode II - Attack of the Clones'],
#  ['Austin Powers: The Spy Who Shagged Me'],
#  ['Princess Bride, The', 'Ghostbusters (a.k.a. Ghost Busters)', 'Shrek'],
#  ['Fear, The',
#   'Air America',
#   'Dangerous Minds',
#   'Great Escape, The',
#   'Hoop Dreams',
#   'Cider House Rules, The',
#   'Dead Man on Campus'],
#  ['Shawshank Redemption, The'],
#  ['Young Frankenstein',
#   'Treasure of the Sierra Madre, The',
#   'Cyrano de Bergerac'],
#  ['Clueless', "Once Upon a Time in the West (C'era una volta il West)"],
#  ['Basic Instinct', 'Matrix, The', 'Jackal, The'],
#  ['Sin City'],
#  ['While You Were Sleeping'],
#  ['Groundhog Day',
#   'Legend of Drunken Master, The (Jui kuen II)',
#   'Running Scared',
#   'Saving Private Ryan',
#   'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2)',
#   'Stand by Me',
#   "She's All That",
#   'Finding Forrester'],
#  ['Right Stuff, The'],
#  ['Splash', 'Dirty Dozen, The'],
#  ['Island, The', 'Rain Man', 'Rainmaker, The'],
#  ['Ernest Goes to Camp',
#   'You Only Live Twice',
#   'Graduate, The',
#   'Men in Black (a.k.a. MIB)',
#   'Casino',
#   'Pacific Rim'],
#  ['Of Mice and Men'],
#  ['Queen of the Damned'],
#  ['Seven (a.k.a. Se7en)'],
#  ['Pursuit of Happiness'],
#  ['Rudy',
#   'Dolores Claiborne',
#   'Dick',
#   'Waiting to Exhale',
#   'Murder at 1600',
#   "Preacher's Wife, The"],
#  ['Star Wars: Episode I - The Phantom Menace'],
#  ['Men in Black (a.k.a. MIB)'],
#  ['Secret Garden, The'],
#  ['Disclosure', 'Usual Suspects, The'],
#  ['Juno'],
#  ['As Good as It Gets'],
#  ['Othello'],
#  ['Englishman Who Went Up a Hill But Came Down a Mountain, The',
#   'Star Wars: Episode VI - Return of the Jedi'],
#  ['Tin Cup', 'Birdcage, The'],
#  ['Mission: Impossible'],
#  ['Mallrats', 'Waking Life'],
#  ['Hero (Ying xiong)'],
#  ['Interview with the Vampire: The Vampire Chronicles',
#   'Enemy of the State',
#   'Ace Ventura: When Nature Calls',
#   'Austin Powers: International Man of Mystery',
#   'Coneheads',
#   'As Good as It Gets'],
#  ['Saving Private Ryan', 'From Russia with Love', 'Aliens', 'Unforgettable'],
#  ['Tender Mercies'],
#  ['Hud'],
#  ['Terminator, The', 'Searchers, The', 'Ben-Hur'],
#  ['Airplane!'],
#  ['Night on Earth', 'Birds, The', 'Tommy'],
#  ['Star Wars: Episode VI - Return of the Jedi',
#   'Miss Congeniality',
#   'Million Dollar Baby',
#   'King Kong',
#   'Quills'],
#  ['True Lies'],
#  ['Pollock'],
#  ['South Park: Bigger, Longer and Uncut',
#   'Lion King, The',
#   'So I Married an Axe Murderer',
#   'Backdraft'],
#  ['Fame'],
#  ['Touch of Evil'],
#  ['Big'],
#  ['Verdict, The', 'Traffic', "Ferris Bueller's Day Off"],
#  ['Léon: The Professional (a.k.a. The Professional) (Léon)',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Smoke'],
#  ['Santa Clause, The'],
#  ['Sleeping Beauty'],
#  ['Rookie of the Year', 'Billy Madison', 'Life as a House', 'Spellbound'],
#  ['Antz', 'Good Morning, Vietnam'],
#  ['Great Balls of Fire!', 'Pulp Fiction'],
#  ['Tombstone'],
#  ['I Know What You Did Last Summer',
#   "Wayne's World",
#   'Wizard of Oz, The',
#   'American President, The',
#   'Dangerous Minds'],
#  ['Trees Lounge',
#   'L.A. Story',
#   'For a Few Dollars More (Per qualche dollaro in più)',
#   'Secrets & Lies',
#   'Independence Day (a.k.a. ID4)',
#   'Diner',
#   'Entrapment',
#   'Tootsie',
#   'Crow, The'],
#  ['Shrek'],
#  ['Things You Can Tell Just by Looking at Her',
#   'Spiderwick Chronicles, The',
#   'Charlie Brown Christmas, A',
#   'Donnie Darko'],
#  ['Richard III'],
#  ['Three Colors: Red (Trois couleurs: Rouge)', 'L.A. Story', 'Lone Star'],
#  ['Scream 3'],
#  ['Last Kiss, The'],
#  ['Non-Stop', 'Rambo: First Blood Part II'],
#  ['Godfather, The', 'Get Shorty'],
#  ['Juror, The', 'Twister'],
#  ['Big Sleep, The'],
#  ['Big Green, The', 'Twister'],
#  ['Mask, The'],
#  ['Tarzan',
#   'Toy Story',
#   "Amelie (Fabuleux destin d'Amélie Poulain, Le)",
#   'Land of the Dead',
#   'Musa the Warrior (Musa)',
#   'Malèna'],
#  ['Back to the Future Part II'],
#  ['Waterworld'],
#  ['Downfall (Untergang, Der)',
#   'Little Miss Sunshine',
#   'Observe and Report',
#   'Pursuit of Happyness, The',
#   '3 Women (Three Women)',
#   'Citizen Kane'],
#  ['School of Rock'],
#  ['21 Grams'],
#  ['North by Northwest', 'Young Sherlock Holmes', 'Say Anything...'],
#  ['Star Wars: Episode V - The Empire Strikes Back', 'Ronin'],
#  ['Purple Rose of Cairo, The', 'Nutty Professor, The'],
#  ['Star Trek VI: The Undiscovered Country'],
#  ['Primal Fear'],
#  ['High Fidelity'],
#  ['Big'],
#  ['Ghost World'],
#  ['Wallace & Gromit: The Wrong Trousers', 'My Big Fat Greek Wedding'],
#  ['Drop Zone', "What's Love Got to Do with It?"],
#  ['Office Space', "Devil's Advocate, The"],
#  ['Star Wars: Episode V - The Empire Strikes Back'],
#  ['Little Miss Sunshine', 'Stepmom', 'Speed'],
#  ['Trainspotting'],
#  ['Rock, The'],
#  ['Three Colors: Red (Trois couleurs: Rouge)'],
#  ['Sabrina'],
#  ['Pocahontas', 'West Side Story', 'Love Letter, The'],
#  ['Hoosiers (a.k.a. Best Shot)',
#   'How the Grinch Stole Christmas (a.k.a. The Grinch)',
#   "Wayne's World"],
#  ['Mind Game', "Howl's Moving Castle (Hauru no ugoku shiro)", 'X-Men'],
#  ['Miracle on 34th Street'],
#  ['Heavy Metal'],
#  ["General's Daughter, The", 'Runaway Bride'],
#  ['French Connection, The'],
#  ['Green Mile, The', 'Requiem for a Dream'],
#  ['Sleepless in Seattle', 'Cool Hand Luke'],
#  ['El Dorado'],
#  ['Sum of All Fears, The',
#   'Willow',
#   'Beverly Hills Ninja',
#   'Clerks',
#   'Ref, The',
#   'Riding the Bullet',
#   'Polar Express, The',
#   'Road Warrior, The (Mad Max 2)',
#   'Ladyhawke',
#   "Breakfast at Tiffany's",
#   'King Arthur'],
#  ['Manhattan Murder Mystery'],
#  ['Escape from L.A.'],
#  ['Ravenous'],
#  ['Grapes of Wrath, The'],
#  ['Toy Story', 'Stupids, The'],
#  ['To Be or Not to Be',
#   'Brave Little Toaster, The',
#   "Bug's Life, A",
#   'Lilo & Stitch',
#   'Matrix, The',
#   'Goodfellas'],
#  ['Perfect World, A',
#   'xXx',
#   'Tommy Boy',
#   'Science of Sleep, The (La science des rêves)',
#   'Abyss, The',
#   "Look Who's Talking",
#   'Dreamgirls',
#   'U.S. Marshals'],
#  ['Exorcist, The'],
#  ['Evil Dead, The',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Green Mile, The',
#   "Wayne's World"],
#  ['James and the Giant Peach', 'Austin Powers: International Man of Mystery'],
#  ['People vs. Larry Flynt, The', 'Road Trip', 'Wizard of Oz, The'],
#  ['Old Boy'],
#  ['Jurassic Park', 'Thing, The'],
#  ['Die Hard'],
#  ['Frost/Nixon', 'Lock, Stock & Two Smoking Barrels', 'Touching the Void'],
#  ['American Buffalo', 'Cold Comfort Farm', 'Galaxy Quest'],
#  ['Gladiator'],
#  ['Hellboy II: The Golden Army'],
#  ['Blank Check', 'Life', 'Snake Eyes', 'Scream'],
#  ['Up'],
#  ['Ever After: A Cinderella Story'],
#  ['Mrs. Doubtfire', 'Sleepless in Seattle', 'Quiz Show'],
#  ["Muriel's Wedding",
#   'Young Frankenstein',
#   'Perez Family, The',
#   "One Flew Over the Cuckoo's Nest"],
#  ['Desperately Seeking Susan', 'Clueless', 'Seven (a.k.a. Se7en)'],
#  ['Fugitive, The',
#   'Young Frankenstein',
#   'E.T. the Extra-Terrestrial',
#   'Interview with the Vampire: The Vampire Chronicles'],
#  ['Usual Suspects, The'],
#  ['Death Becomes Her'],
#  ["It's a Wonderful Life",
#   'Prestige, The',
#   'Watchmen',
#   'Being John Malkovich',
#   'Truman Show, The',
#   'Notting Hill',
#   'Just Another Love Story (Kærlighed på film)',
#   'Pursuit of Happyness, The'],
#  ['Family Thing, A', 'Unstrung Heroes'],
#  ['Mars Attacks!'],
#  ["What's Eating Gilbert Grape"],
#  ['13 Going on 30'],
#  ['Losing Isaiah',
#   'Princess Bride, The',
#   'My Left Foot',
#   'Honeymoon in Vegas',
#   'Sense and Sensibility',
#   'I, Robot',
#   'Jaws'],
#  ['Anastasia'],
#  ['Forrest Gump', 'Platoon'],
#  ['Cape Fear'],
#  ['Stand by Me'],
#  ['Star Wars: Episode VI - Return of the Jedi', 'Go'],
#  ['Few Good Men, A', 'Gods Must Be Crazy, The', 'Hercules', 'Prom Night'],
#  ['Weird Science',
#   'Citizen Kane',
#   'Wallace & Gromit: A Close Shave',
#   'Frankenstein'],
#  ['Lost Highway',
#   'Clerks',
#   'Kung Fu Hustle (Gong fu)',
#   'Suspiria',
#   '28 Days Later',
#   'Ed Wood'],
#  ['Just Married',
#   'Fight Club',
#   'Red Dragon',
#   'Scent of a Woman',
#   'Go',
#   'Waterworld'],
#  ['Gran Torino', 'Eight Legged Freaks'],
#  ['Great Expectations',
#   'American History X',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'About Schmidt'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ['Pulp Fiction'],
#  ['Psycho'],
#  ['Third Man, The'],
#  ["Antonia's Line (Antonia)"],
#  ['Goodfellas', 'Hills Have Eyes II, The'],
#  ['Last of the Mohicans, The', 'Princess Diaries, The', 'Mighty Ducks, The'],
#  ['Forrest Gump'],
#  ['Cocoon'],
#  ['Ghost Dog: The Way of the Samurai'],
#  ['Unstrung Heroes', 'Forrest Gump'],
#  ['Fight Club'],
#  ['Butch Cassidy and the Sundance Kid',
#   'Talented Mr. Ripley, The',
#   'Cape Fear',
#   'Liar Liar',
#   'As Good as It Gets'],
#  ['Clockwork Orange, A',
#   'Mary Poppins',
#   'X2: X-Men United',
#   'Saving Private Ryan',
#   'High Society'],
#  ['Deuce Bigalow: Male Gigolo',
#   'Sherlock Holmes',
#   'Eternal Sunshine of the Spotless Mind'],
#  ['Bananas', 'Seven Beauties (Pasqualino Settebellezze)', 'Shrek'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ['Adventures in Babysitting',
#   'Notting Hill',
#   'My Cousin Vinny',
#   'Sleepless in Seattle',
#   'NeverEnding Story II: The Next Chapter, The',
#   'Young Guns'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)'],
#  ['Replacements, The', 'Walk on the Moon, A', 'Blast from the Past'],
#  ['Mummy, The'],
#  ['Twilight'],
#  ['Interview with the Vampire: The Vampire Chronicles',
#   'Sixth Sense, The',
#   'Caddyshack'],
#  ['City of God (Cidade de Deus)', 'Eyes Wide Shut'],
#  ['Home Alone', 'Broken Arrow', 'In the Line of Fire'],
#  ['L.A. Confidential'],
#  ['Mission: Impossible',
#   'Powder',
#   'Trainspotting',
#   'Million Dollar Baby',
#   'Iron Man'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)', 'In & Out'],
#  ['Star Wars: Episode III - Revenge of the Sith',
#   'Lord of the Rings: The Fellowship of the Ring, The'],
#  ["Amores Perros (Love's a Bitch)",
#   "One Flew Over the Cuckoo's Nest",
#   'Shining, The'],
#  ['French Connection, The',
#   'Snapper, The',
#   'High Fidelity',
#   'Far from Heaven',
#   'Remains of the Day, The',
#   'Strictly Ballroom'],
#  ['Jurassic Park'],
#  ['1408',
#   'From Dusk Till Dawn',
#   'Cloverfield',
#   'Titanic',
#   'Last King of Scotland, The',
#   'Die Hard 2'],
#  ['Mission: Impossible'],
#  ['Nico Icon', 'Priest'],
#  ['Piano, The'],
#  ['Saving Private Ryan'],
#  ['Better Off Dead...',
#   'Wild Things',
#   'Made in America',
#   'L.A. Confidential',
#   'Battlefield Earth'],
#  ['Sideways',
#   'Girl, Interrupted',
#   'Michael',
#   'Magdalene Sisters, The',
#   'Life of Pi',
#   'Con Air'],
#  ['Junior'],
#  ['Jumanji'],
#  ['Matrix, The', 'Pulp Fiction'],
#  ['Clear and Present Danger', 'Natural Born Killers'],
#  ['Back to the Future'],
#  ['Legally Blonde', 'Matchstick Men', 'My Dog Skip'],
#  ['Black Dahlia, The', 'Titanic'],
#  ['Die Hard: With a Vengeance'],
#  ['Frost/Nixon'],
#  ["One Flew Over the Cuckoo's Nest"],
#  ['Sleeping Beauty',
#   'Color Purple, The',
#   'Celebration, The (Festen)',
#   'Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die)',
#   'Pillow Book, The',
#   'Wings of Desire (Himmel über Berlin, Der)',
#   'Drugstore Cowboy'],
#  ['Die Hard', 'Men in Black (a.k.a. MIB)'],
#  ['Thief',
#   'Heat',
#   'Léon: The Professional (a.k.a. The Professional) (Léon)',
#   'Titanic',
#   'Graduate, The',
#   'Bourne Supremacy, The',
#   'Odd Couple, The',
#   'Crimes and Misdemeanors'],
#  ['Corrina, Corrina'],
#  ["Boundin'",
#   'Miss Pettigrew Lives for a Day',
#   'X-Men Origins: Wolverine',
#   'Flight of the Phoenix',
#   'Dreamer: Inspired by a True Story',
#   'Memoirs of a Geisha'],
#  ['Love and Other Catastrophes'],
#  ['Rush Hour 2', 'Raging Bull'],
#  ['Independence Day (a.k.a. ID4)', 'Austin Powers in Goldmember'],
#  ['Parent Trap, The', 'Atlantis: The Lost Empire', 'Cats & Dogs'],
#  ['M*A*S*H (a.k.a. MASH)',
#   "Logan's Run",
#   'Places in the Heart',
#   "General's Daughter, The",
#   'Adventures of Robin Hood, The'],
#  ['Persepolis'],
#  ['Donnie Darko'],
#  ['Mission: Impossible'],
#  ['Matrix, The', 'Planet of the Apes', 'Cape Fear'],
#  ['Casino', 'Houseguest'],
#  ['Home Alone', 'Sleepless in Seattle'],
#  ['Thelma & Louise'],
#  ['Rear Window'],
#  ['Nell', 'Leaving Las Vegas'],
#  ['Kung Fu Hustle (Gong fu)', 'FLCL'],
#  ['Hotel Rwanda',
#   'Hannibal',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Good Will Hunting',
#   'In the Bedroom',
#   'Notorious'],
#  ['Wedding Crashers', 'Score, The'],
#  ['Six Degrees of Separation', 'Funeral, The'],
#  ['Shipping News, The', 'Tea with Mussolini'],
#  ['Army of Darkness'],
#  ['Man, The', 'High Fidelity', 'No Country for Old Men'],
#  ['Mystery Men',
#   'Chicken Run',
#   'Seventh Seal, The (Sjunde inseglet, Det)',
#   'Mystery Science Theater 3000: The Movie',
#   'Ronin'],
#  ['Forrest Gump'],
#  ['Mask, The'],
#  ['Training Day', '10 Things I Hate About You'],
#  ['Terminator 2: Judgment Day'],
#  ['GoldenEye'],
#  ['Hulk'],
#  ['Willy Wonka & the Chocolate Factory'],
#  ['Dances with Wolves',
#   'Silence of the Lambs, The',
#   '¡Three Amigos!',
#   'Star Trek: Insurrection',
#   'Starship Troopers',
#   'Thin Red Line, The',
#   'Grease 2'],
#  ['Toy Story'],
#  ['Star Wars: Episode IV - A New Hope',
#   'Paradise Lost: The Child Murders at Robin Hood Hills',
#   'Last King of Scotland, The',
#   'Apollo 13',
#   '13 Assassins (Jûsan-nin no shikaku)',
#   'Girl with the Dragon Tattoo, The',
#   'Stripes',
#   'Aladdin'],
#  ['Judge Dredd'],
#  ['Manchurian Candidate, The', 'Magnolia'],
#  ['Contact'],
#  ['Twelve Monkeys (a.k.a. 12 Monkeys)', 'Mallrats', 'American History X'],
#  ['Conan the Destroyer', 'Silence of the Lambs, The'],
#  ['Up',
#   'Madagascar',
#   'Best Little Whorehouse in Texas, The',
#   'Chocolat',
#   'Hellboy II: The Golden Army',
#   'Miss Congeniality',
#   'Bubba Ho-tep',
#   "Wayne's World 2"],
#  ['Frequency', 'Ginger Snaps', 'Judge Dredd'],
#  ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   "Claire's Knee (Genou de Claire, Le)",
#   'Anatomy of a Murder',
#   'Strangers on a Train',
#   'L.A. Story'],
#  ['Forbidden Zone',
#   'Wedding Singer, The',
#   'Sword in the Stone, The',
#   'Help!',
#   '2001: A Space Odyssey',
#   'Star Trek VI: The Undiscovered Country',
#   'Judge Dredd'],
#  ["One Flew Over the Cuckoo's Nest",
#   'Raising Arizona',
#   'Terminator, The',
#   'Fly, The'],
#  ['Psycho', 'Gladiator'],
#  ['Beverly Hills Cop'],
#  ['Dances with Wolves'],
#  ['Donnie Darko',
#   'Let the Right One In (Låt den rätte komma in)',
#   'Collection, The',
#   'Sleepy Hollow',
#   'Marmaduke',
#   'Inception',
#   'Thank You for Smoking',
#   'Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers)',
#   'Clan of the Cave Bear, The',
#   'Hellraiser: Hellseeker',
#   "Ferris Bueller's Day Off",
#   'Hellraiser'],
#  ['Metropolis'],
#  ['River Wild, The'],
#  ["Bon Voyage, Charlie Brown (and Don't Come Back!)",
#   'Fight Club',
#   'Skulls, The',
#   'Independence Day (a.k.a. ID4)',
#   'Airplane!',
#   'Winnie the Pooh and the Blustery Day',
#   'Matewan',
#   'What Dreams May Come',
#   'Dernier Combat, Le (Last Battle, The)',
#   'Up the Academy',
#   'Long Goodbye, The',
#   'Arachnophobia',
#   'Call Northside 777',
#   'Chasing Amy',
#   'Joe Versus the Volcano',
#   'Hot to Trot',
#   'Rambling Rose'],
#  ['Natural Born Killers',
#   "Don't Be a Menace to South Central While Drinking Your Juice in the Hood"],
#  ['Animal House'],
#  ['Thirteenth Floor, The'],
#  ['Terminator, The'],
#  ['Usual Suspects, The'],
#  ['Pride and Prejudice'],
#  ['Darjeeling Limited, The'],
#  ['Rock, The'],
#  ['Bio-Dome', 'Braveheart'],
#  ['Goodfellas', 'Philadelphia', 'Memento'],
#  ["Ferris Bueller's Day Off"],
#  ['Beautiful Mind, A',
#   'Sunshine',
#   'Memento',
#   'Bride & Prejudice',
#   'Babel',
#   'Prestige, The'],
#  ['Any Given Sunday'],
#  ['African Queen, The'],
#  ['While You Were Sleeping'],
#  ['Casablanca'],
#  ['Seven Samurai (Shichinin no samurai)'],
#  ['Chicken Run'],
#  ['Godfather, The'],
#  ['Star Trek: First Contact', 'Bad Santa'],
#  ['Jack'],
#  ['Clerks', 'Free Willy'],
#  ['Mondays in the Sun (Lunes al sol, Los)',
#   'Black Cauldron, The',
#   'Welcome to Mooseport',
#   'For a Few Dollars More (Per qualche dollaro in più)',
#   'Buena Vista Social Club',
#   'Layer Cake',
#   'Juno',
#   'Star Trek VI: The Undiscovered Country'],
#  ['Heavy Metal',
#   'Net, The',
#   'Mystery Men',
#   'Star Trek: The Motion Picture',
#   'Faces of Death 5',
#   'Rambo III'],
#  ['Time to Kill, A'],
#  ['Who Framed Roger Rabbit?', 'Back to the Future', 'Super Troopers'],
#  ...]

# %%
itemsets, rules = apriori(lst, min_support=0.009,  min_confidence=0.3)
rules
# Out:
# []

# %%
#itemsets, rules =  apriori(lst, min_support=0.005, min_confidence=0.4)
#rules

# %%
rules=sorted(rules, key=lambda rule: rule.confidence)
for rule in rules:
  print(rule)
